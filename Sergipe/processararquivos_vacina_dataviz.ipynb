# %% [markdown]
# # Processamento de Dados da Vacinação Sergipe

# %%
import pandas as pd
import numpy as np

# %%
populacao_sergipe = 2318822

# %%
# Carrega os dados por município e grupo
data_total_municipio = pd.read_csv("output/relatorio_vacina_sergipe.csv")

# Carrega arquivo de histórico por data
data_historico_estado = pd.read_excel("data_general/historico_sergipe.xlsx")

# %%
data_total_municipio
# Out:
#     codigo_municipio                municipio  populacao_total  \
# 0             280010  Amparo de São Francisco             2380
# 1             280020                 Aquidabã            21681
# 2             280030                  Aracaju           664908
# 3             280040                    Arauá             9947
# 4             280050             Areia Branca            18686
# ..               ...                      ...              ...
# 70            280720                   Siriri             8970
# 71            280730                    Telha             3249
# 72            280740           Tobias Barreto            52530
# 73            280750            Tomar do Geru            13535
# 74            280760                  Umbaúba            25550
#
#     populacao_grupo4_80mais  populacao_grupo5_7079  populacao_grupo6_6069  \
# 0                        51                     89                    140
# 1                       481                    932                   1543
# 2                     10149                  24138                  47854
# 3                       149                    348                    644
# 4                       281                    548                   1047
# ..                      ...                    ...                    ...
# 70                      154                    316                    533
# 71                       49                    100                    178
# 72                     1046                   2188                   3513
# 73                      208                    446                    760
# 74                      308                    725                   1482
#
#     enviadas_dose1  enviadas_dose2  enviadas_dose_unica  aplicadas_dose1  ...  \
# 0             1587            1235                   30             1548  ...
# 1            14433            9036                  210            12560  ...
# 2           460155          288592                12715           444850  ...
# 3             6477            4289                  100             6568  ...
# 4            12054            7554                  185            12282  ...
# ..             ...             ...                  ...              ...  ...
# 70            5490            3683                   75             5034  ...
# 71            2121            1417                   45             2032  ...
# 72           34482           19584                 1160            34551  ...
# 73            8901            5339                  135             6898  ...
# 74           16253            9586                  240            14736  ...
#
#     aplicadas_dose_unica_grupo30_gestantes  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ..                                     ...
# 70                                       0
# 71                                       0
# 72                                       0
# 73                                       0
# 74                                       0
#
#     aplicadas_dose_unica_grupo31_puerperas  aplicadas_dose_unica_grupo32_3539  \
# 0                                        0                                 11
# 1                                        0                                133
# 2                                        1                                262
# 3                                        0                                  0
# 4                                        0                                 47
# ..                                     ...                                ...
# 70                                       0                                 17
# 71                                       0                                  0
# 72                                       0                                 42
# 73                                       0                                139
# 74                                       0                                117
#
#     aplicadas_dose_unica_grupo33_3034  aplicadas_dose_unica_grupo34_lactante  \
# 0                                   3                                      0
# 1                                   0                                      0
# 2                                  37                                      0
# 3                                   0                                      0
# 4                                   2                                      0
# ..                                ...                                    ...
# 70                                  0                                      0
# 71                                  0                                      0
# 72                                  0                                      0
# 73                                  0                                      0
# 74                                 41                                      0
#
#     aplicadas_dose_unica_grupo35_2529  aplicadas_dose_unica_grupo36_2024  \
# 0                                   1                                  0
# 1                                   0                                  0
# 2                                 334                                  3
# 3                                   0                                  0
# 4                                   0                                  0
# ..                                ...                                ...
# 70                                  0                                  0
# 71                                  0                                  0
# 72                                  0                                  0
# 73                                  0                                  0
# 74                                  0                                  0
#
#     aplicadas_dose_unica_grupo37_1819  aplicadas_dose_unica_grupo38_1517  \
# 0                                   0                                  0
# 1                                   0                                  0
# 2                                  87                                  0
# 3                                   0                                  0
# 4                                   0                                  0
# ..                                ...                                ...
# 70                                  0                                  0
# 71                                  0                                  0
# 72                                  0                                  0
# 73                                  0                                  0
# 74                                  0                                  0
#
#     aplicadas_dose_unica_grupo39_1214
# 0                                   0
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
# ..                                ...
# 70                                  0
# 71                                  0
# 72                                  0
# 73                                  0
# 74                                  0
#
# [75 rows x 117 columns]

# %%
data_historico_estado
# Out:
#           data  enviadas_dose1  aplicadas_dose1  enviadas_dose2  \
# 0   2021-03-01           54898            45836           28258
# 1   2021-03-02           78109            48907           35377
# 2   2021-03-03           78109            54155           35377
# 3   2021-03-04           78109            61270           35377
# 4   2021-03-05           92630            67793           35377
# ..         ...             ...              ...             ...
# 166 2021-09-08         1505856          1436753          800786
# 167 2021-09-09         1527766          1443028          914366
# 168 2021-09-10         1527766          1451814          914366
# 169 2021-09-11         1527766          1453771          914366
# 170 2021-09-13         1527766          1462728          914366
#
#      aplicadas_dose2  enviadas_dose_unica  aplicadas_dose_unica
# 0              24909                    0                     0
# 1              25744                    0                     0
# 2              26816                    0                     0
# 3              27275                    0                     0
# 4              28353                    0                     0
# ..               ...                  ...                   ...
# 166           565854                39750                 39952
# 167           588034                39750                 39952
# 168           602888                39750                 39952
# 169           606539                39750                 39952
# 170           634665                39750                 39952
#
# [171 rows x 7 columns]

# %% [markdown]
# ## Geração do Arquivo de Total de Doses Enviadas e Aplicadas por Município

# %%
filter_historico = data_total_municipio[['codigo_municipio','municipio','populacao_total','enviadas_dose1','aplicadas_dose1','enviadas_dose2','aplicadas_dose2','enviadas_dose_unica','aplicadas_dose_unica']]

# %%
total_sergipe = data_historico_estado.tail(1)

# %%
new_line = ['000000','TODO ESTADO',2318822,int(total_sergipe['enviadas_dose1']),int(total_sergipe['aplicadas_dose1']),int(total_sergipe['enviadas_dose2']),int(total_sergipe['aplicadas_dose2']), int(total_sergipe['enviadas_dose_unica']), int(total_sergipe['aplicadas_dose_unica'])]
new_line
# Out:
# ['000000',
#  'TODO ESTADO',
#  2318822,
#  1527766,
#  1462728,
#  914366,
#  634665,
#  39750,
#  39952]

# %%
data_total_final = filter_historico.append(pd.Series(new_line, index=filter_historico.columns), ignore_index=True)

# %%
data_total_final['cobertura_pop_dose1'] = data_total_final['aplicadas_dose1'] / data_total_final['populacao_total']
data_total_final['cobertura_pop_dose2'] = data_total_final['aplicadas_dose2'] / data_total_final['populacao_total']
data_total_final['cobertura_pop_dose2_dose_unica'] = (data_total_final['aplicadas_dose2'] + data_total_final['aplicadas_dose_unica']) / data_total_final['populacao_total']

# %%
data_total_final
# Out:
#    codigo_municipio                municipio  populacao_total  enviadas_dose1  \
# 0            280010  Amparo de São Francisco             2380            1587
# 1            280020                 Aquidabã            21681           14433
# 2            280030                  Aracaju           664908          460155
# 3            280040                    Arauá             9947            6477
# 4            280050             Areia Branca            18686           12054
# ..              ...                      ...              ...             ...
# 71           280730                    Telha             3249            2121
# 72           280740           Tobias Barreto            52530           34482
# 73           280750            Tomar do Geru            13535            8901
# 74           280760                  Umbaúba            25550           16253
# 75           000000              TODO ESTADO          2318822         1527766
#
#     aplicadas_dose1  enviadas_dose2  aplicadas_dose2  enviadas_dose_unica  \
# 0              1548            1235             1004                   30
# 1             12560            9036             5850                  210
# 2            444850          288592           188307                12715
# 3              6568            4289             3099                  100
# 4             12282            7554             6009                  185
# ..              ...             ...              ...                  ...
# 71             2032            1417             1086                   45
# 72            34551           19584            15339                 1160
# 73             6898            5339             3175                  135
# 74            14736            9586             6184                  240
# 75          1462728          914366           634665                39750
#
#     aplicadas_dose_unica  cobertura_pop_dose1  cobertura_pop_dose2  \
# 0                     30             0.650420             0.421849
# 1                    210             0.579309             0.269822
# 2                  12517             0.669040             0.283208
# 3                    102             0.660300             0.311551
# 4                    198             0.657284             0.321578
# ..                   ...                  ...                  ...
# 71                    46             0.625423             0.334257
# 72                  1187             0.657738             0.292005
# 73                   139             0.509642             0.234577
# 74                   237             0.576751             0.242035
# 75                 39952             0.630807             0.273701
#
#     cobertura_pop_dose2_dose_unica
# 0                         0.434454
# 1                         0.279507
# 2                         0.302033
# 3                         0.321806
# 4                         0.332174
# ..                             ...
# 71                        0.348415
# 72                        0.314601
# 73                        0.244847
# 74                        0.251311
# 75                        0.290931
#
# [76 rows x 12 columns]

# %%
data_total_final.to_csv("output/data_vacinas_municipio.csv",index=False)

# %% [markdown]
# ## Geração do Arquivo de Histórico da vacinação do Estado com Média Móvel

# %%
data_historico_estado[['data','aplicadas_dose1','aplicadas_dose2','aplicadas_dose_unica']].copy()
# Out:
#           data  aplicadas_dose1  aplicadas_dose2  aplicadas_dose_unica
# 0   2021-03-01            45836            24909                     0
# 1   2021-03-02            48907            25744                     0
# 2   2021-03-03            54155            26816                     0
# 3   2021-03-04            61270            27275                     0
# 4   2021-03-05            67793            28353                     0
# ..         ...              ...              ...                   ...
# 166 2021-09-08          1436753           565854                 39952
# 167 2021-09-09          1443028           588034                 39952
# 168 2021-09-10          1451814           602888                 39952
# 169 2021-09-11          1453771           606539                 39952
# 170 2021-09-13          1462728           634665                 39952
#
# [171 rows x 4 columns]

# %%
# Calcula a média móvel e o total por dia
total_historico = data_historico_estado[['data','enviadas_dose1','enviadas_dose2','aplicadas_dose1','aplicadas_dose2','enviadas_dose_unica','aplicadas_dose_unica']].copy()
total_historico['diario_dose1'] = total_historico['aplicadas_dose1'].diff()
total_historico['diario_dose2'] = total_historico['aplicadas_dose2'].diff()
total_historico['diario_dose_unica'] = total_historico['aplicadas_dose_unica'].diff()
total_historico['mediamovel_dose1'] = total_historico['diario_dose1'].rolling(window=7).mean()
total_historico['mediamovel_dose2'] = total_historico['diario_dose2'].rolling(window=7).mean()
total_historico['mediamovel_dose_unica'] = total_historico['diario_dose_unica'].rolling(window=7).mean()
total_historico['mediadiaria_dose1'] = total_historico['diario_dose1'].expanding().mean()
total_historico['mediadiaria_dose2'] = total_historico['diario_dose2'].expanding().mean()
total_historico['mediadiaria_dose_unica'] = total_historico['diario_dose_unica'].expanding().mean()
total_historico['percent_uso_dose1'] = total_historico['aplicadas_dose1'] / total_historico['enviadas_dose1']
total_historico['percent_uso_dose2'] = total_historico['aplicadas_dose2'] / total_historico['enviadas_dose2']
total_historico['percent_uso_dose_unica'] = total_historico['aplicadas_dose_unica'] / total_historico['enviadas_dose_unica']
total_historico['percent_populacao_parcialmente'] = total_historico['aplicadas_dose1'] / populacao_sergipe
total_historico['percent_populacao_totalmente'] = (total_historico['aplicadas_dose2'] + total_historico['aplicadas_dose_unica']) / populacao_sergipe
total_historico = total_historico.fillna(0)
total_historico
# Out:
#           data  enviadas_dose1  enviadas_dose2  aplicadas_dose1  \
# 0   2021-03-01           54898           28258            45836
# 1   2021-03-02           78109           35377            48907
# 2   2021-03-03           78109           35377            54155
# 3   2021-03-04           78109           35377            61270
# 4   2021-03-05           92630           35377            67793
# ..         ...             ...             ...              ...
# 166 2021-09-08         1505856          800786          1436753
# 167 2021-09-09         1527766          914366          1443028
# 168 2021-09-10         1527766          914366          1451814
# 169 2021-09-11         1527766          914366          1453771
# 170 2021-09-13         1527766          914366          1462728
#
#      aplicadas_dose2  enviadas_dose_unica  aplicadas_dose_unica  diario_dose1  \
# 0              24909                    0                     0           0.0
# 1              25744                    0                     0        3071.0
# 2              26816                    0                     0        5248.0
# 3              27275                    0                     0        7115.0
# 4              28353                    0                     0        6523.0
# ..               ...                  ...                   ...           ...
# 166           565854                39750                 39952        1676.0
# 167           588034                39750                 39952        6275.0
# 168           602888                39750                 39952        8786.0
# 169           606539                39750                 39952        1957.0
# 170           634665                39750                 39952        8957.0
#
#      diario_dose2  diario_dose_unica  ...  mediamovel_dose2  \
# 0             0.0                0.0  ...          0.000000
# 1           835.0                0.0  ...          0.000000
# 2          1072.0                0.0  ...          0.000000
# 3           459.0                0.0  ...          0.000000
# 4          1078.0                0.0  ...          0.000000
# ..            ...                ...  ...               ...
# 166       12997.0                0.0  ...      10803.142857
# 167       22180.0                0.0  ...      12924.714286
# 168       14854.0                0.0  ...      13370.857143
# 169        3651.0                0.0  ...      11479.142857
# 170       28126.0                0.0  ...      14127.571429
#
#      mediamovel_dose_unica  mediadiaria_dose1  mediadiaria_dose2  \
# 0                      0.0           0.000000           0.000000
# 1                      0.0        3071.000000         835.000000
# 2                      0.0        4159.500000         953.500000
# 3                      0.0        5144.666667         788.666667
# 4                      0.0        5489.250000         861.000000
# ..                     ...                ...                ...
# 166                    0.0        8379.018072        3258.704819
# 167                    0.0        8366.419162        3372.005988
# 168                    0.0        8368.916667        3440.351190
# 169                    0.0        8330.976331        3441.597633
# 170                    0.0        8334.658824        3586.800000
#
#      mediadiaria_dose_unica  percent_uso_dose1  percent_uso_dose2  \
# 0                  0.000000           0.834930           0.881485
# 1                  0.000000           0.626138           0.727704
# 2                  0.000000           0.693326           0.758007
# 3                  0.000000           0.784417           0.770981
# 4                  0.000000           0.731869           0.801453
# ..                      ...                ...                ...
# 166              240.674699           0.954110           0.706623
# 167              239.233533           0.944535           0.643106
# 168              237.809524           0.950286           0.659351
# 169              236.402367           0.951567           0.663344
# 170              235.011765           0.957429           0.694104
#
#      percent_uso_dose_unica  percent_populacao_parcialmente  \
# 0                  0.000000                        0.019767
# 1                  0.000000                        0.021091
# 2                  0.000000                        0.023355
# 3                  0.000000                        0.026423
# 4                  0.000000                        0.029236
# ..                      ...                             ...
# 166                1.005082                        0.619605
# 167                1.005082                        0.622311
# 168                1.005082                        0.626100
# 169                1.005082                        0.626944
# 170                1.005082                        0.630807
#
#      percent_populacao_totalmente
# 0                        0.010742
# 1                        0.011102
# 2                        0.011564
# 3                        0.011762
# 4                        0.012227
# ..                            ...
# 166                      0.261256
# 167                      0.270821
# 168                      0.277227
# 169                      0.278801
# 170                      0.290931
#
# [171 rows x 21 columns]

# %%
total_historico.to_csv("output/data_vacinas_historico.csv", index=False)

# %% [markdown]
# ## Geração do Arquivo de Total por Grupos de Vacinação

# %%
grupos = {
    1: 'Trabalhadores da Saúde',
    2: 'Pessoas com 60 anos ou mais e deficientes Institucionalizados',
    3: 'Índio Aldeado',
    4: 'Pessoas com 80 anos e mais',
    5: 'Pessoas de 70 a 79 anos', 
    6: 'Pessoas de 60 a 69 anos',
    7: 'Situação de Rua',
    8: 'Quilombolas',
    9: 'Trabalhadores das forças de segurança',
    10: 'Pessoas com Síndrome de Dowm e Autismo',
    11: 'Outros (População vacinada com resíduos de vacinas ao final do dia)',
    12: 'Puerperas com comorbidade',
    13: 'Gestante com comorbidade',
    14: 'Deficiente Permanente',
    15: 'Comorbidades',
    16: 'Trabalhadores da Educação',
    17: 'Trabalhadores do sistema prisional',
    18: 'Privados de liberdade',
    19: 'Trabalhadores do Transporte aéreo',
    20: 'Trabalhadores da Limpeza Urbana',
    21: 'Trabalhadores do Transporte Coletivo',
    22: 'Caminhoneiros',
    23: 'População de 55 a 59 anos',
    24: 'Trabalhadores da Educação Superior',
    25: 'Trabalhadores da Zona Portuária',
    26: 'Trabalhadores Industriais e Civil',
    27: 'População de 50 a 54 anos',
    28: 'População de 45 a 49 anos',
    29: 'População de 40 a 44 anos',
    30: 'Gestantes',
    31: 'Puerperas',
    32: 'População de 35 a 39 anos',
    33: 'População de 30 a 34 anos',
    34: 'Lactantes',
    35: 'População de 25 a 29 anos',
    36: 'População de 20 a 24 anos',
    37: 'População de 18 e 19 anos',
    38: 'População de 15 a 17 anos',
    39: 'População de 12 a 14 anos'
}

# %%
data_total_municipio
# Out:
#     codigo_municipio                municipio  populacao_total  \
# 0             280010  Amparo de São Francisco             2380
# 1             280020                 Aquidabã            21681
# 2             280030                  Aracaju           664908
# 3             280040                    Arauá             9947
# 4             280050             Areia Branca            18686
# ..               ...                      ...              ...
# 70            280720                   Siriri             8970
# 71            280730                    Telha             3249
# 72            280740           Tobias Barreto            52530
# 73            280750            Tomar do Geru            13535
# 74            280760                  Umbaúba            25550
#
#     populacao_grupo4_80mais  populacao_grupo5_7079  populacao_grupo6_6069  \
# 0                        51                     89                    140
# 1                       481                    932                   1543
# 2                     10149                  24138                  47854
# 3                       149                    348                    644
# 4                       281                    548                   1047
# ..                      ...                    ...                    ...
# 70                      154                    316                    533
# 71                       49                    100                    178
# 72                     1046                   2188                   3513
# 73                      208                    446                    760
# 74                      308                    725                   1482
#
#     enviadas_dose1  enviadas_dose2  enviadas_dose_unica  aplicadas_dose1  ...  \
# 0             1587            1235                   30             1548  ...
# 1            14433            9036                  210            12560  ...
# 2           460155          288592                12715           444850  ...
# 3             6477            4289                  100             6568  ...
# 4            12054            7554                  185            12282  ...
# ..             ...             ...                  ...              ...  ...
# 70            5490            3683                   75             5034  ...
# 71            2121            1417                   45             2032  ...
# 72           34482           19584                 1160            34551  ...
# 73            8901            5339                  135             6898  ...
# 74           16253            9586                  240            14736  ...
#
#     aplicadas_dose_unica_grupo30_gestantes  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ..                                     ...
# 70                                       0
# 71                                       0
# 72                                       0
# 73                                       0
# 74                                       0
#
#     aplicadas_dose_unica_grupo31_puerperas  aplicadas_dose_unica_grupo32_3539  \
# 0                                        0                                 11
# 1                                        0                                133
# 2                                        1                                262
# 3                                        0                                  0
# 4                                        0                                 47
# ..                                     ...                                ...
# 70                                       0                                 17
# 71                                       0                                  0
# 72                                       0                                 42
# 73                                       0                                139
# 74                                       0                                117
#
#     aplicadas_dose_unica_grupo33_3034  aplicadas_dose_unica_grupo34_lactante  \
# 0                                   3                                      0
# 1                                   0                                      0
# 2                                  37                                      0
# 3                                   0                                      0
# 4                                   2                                      0
# ..                                ...                                    ...
# 70                                  0                                      0
# 71                                  0                                      0
# 72                                  0                                      0
# 73                                  0                                      0
# 74                                 41                                      0
#
#     aplicadas_dose_unica_grupo35_2529  aplicadas_dose_unica_grupo36_2024  \
# 0                                   1                                  0
# 1                                   0                                  0
# 2                                 334                                  3
# 3                                   0                                  0
# 4                                   0                                  0
# ..                                ...                                ...
# 70                                  0                                  0
# 71                                  0                                  0
# 72                                  0                                  0
# 73                                  0                                  0
# 74                                  0                                  0
#
#     aplicadas_dose_unica_grupo37_1819  aplicadas_dose_unica_grupo38_1517  \
# 0                                   0                                  0
# 1                                   0                                  0
# 2                                  87                                  0
# 3                                   0                                  0
# 4                                   0                                  0
# ..                                ...                                ...
# 70                                  0                                  0
# 71                                  0                                  0
# 72                                  0                                  0
# 73                                  0                                  0
# 74                                  0                                  0
#
#     aplicadas_dose_unica_grupo39_1214
# 0                                   0
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
# ..                                ...
# 70                                  0
# 71                                  0
# 72                                  0
# 73                                  0
# 74                                  0
#
# [75 rows x 117 columns]

# %%
# Organizando as colunas como linhas da tabela
data_group = data_total_municipio.drop(columns=['populacao_total',
       'populacao_grupo4_80mais', 'populacao_grupo5_7079',
       'populacao_grupo6_6069', 'enviadas_dose1', 'enviadas_dose2', 'enviadas_dose_unica', 'aplicadas_dose_unica',
       'aplicadas_dose1', 'aplicadas_dose2'])
data_group = pd.melt(data_group, id_vars=['codigo_municipio','municipio'], value_name='total')
data_group
# Out:
#       codigo_municipio                municipio  \
# 0               280010  Amparo de São Francisco
# 1               280020                 Aquidabã
# 2               280030                  Aracaju
# 3               280040                    Arauá
# 4               280050             Areia Branca
# ...                ...                      ...
# 7870            280720                   Siriri
# 7871            280730                    Telha
# 7872            280740           Tobias Barreto
# 7873            280750            Tomar do Geru
# 7874            280760                  Umbaúba
#
#                                variable  total
# 0          aplicadas_dose1_grupo1_saude     72
# 1          aplicadas_dose1_grupo1_saude    473
# 2          aplicadas_dose1_grupo1_saude  39121
# 3          aplicadas_dose1_grupo1_saude    174
# 4          aplicadas_dose1_grupo1_saude    300
# ...                                 ...    ...
# 7870  aplicadas_dose_unica_grupo39_1214      0
# 7871  aplicadas_dose_unica_grupo39_1214      0
# 7872  aplicadas_dose_unica_grupo39_1214      0
# 7873  aplicadas_dose_unica_grupo39_1214      0
# 7874  aplicadas_dose_unica_grupo39_1214      0
#
# [7875 rows x 4 columns]

# %%
## Funções Auxiliares para mapear informações em novas colunas

import re
def function_map(row, index, convert=False):
    split_ = row['variable'].split("_")

    if len(split_) == 3:
        if index == 1:
            split_value = -1
        else:
            split_value = 99
    elif len(split_) == 4:
        split_value = split_[index]
        if convert:
            split_value = list(map(int, re.findall(r'\d+',  split_value)))[0]
            
    else:
        if index == 1:
            split_value = split_[1] + "_" + split_[2]
            split_value = -1
        elif index == 2:
            split_value = split_[3]
            if convert:
                split_value = list(map(int, re.findall(r'\d+',  split_value)))[0]
            
    
            
    return split_value

def grupos_map(row): 
    return grupos[row['grupo']]

# %%
# Criando novas colunas
data_group['dose'] = data_group.apply(lambda row: function_map(row, 1, True), axis=1)
data_group['grupo'] = data_group.apply(lambda row: function_map(row, 2, True), axis=1)
data_group['nome_grupo'] = data_group.apply(lambda row: grupos_map(row), axis=1)

# %%
data_group = data_group.drop(columns=['variable'])
data_group
# Out:
#       codigo_municipio                municipio  total  dose  grupo  \
# 0               280010  Amparo de São Francisco     72     1      1
# 1               280020                 Aquidabã    473     1      1
# 2               280030                  Aracaju  39121     1      1
# 3               280040                    Arauá    174     1      1
# 4               280050             Areia Branca    300     1      1
# ...                ...                      ...    ...   ...    ...
# 7870            280720                   Siriri      0    -1     39
# 7871            280730                    Telha      0    -1     39
# 7872            280740           Tobias Barreto      0    -1     39
# 7873            280750            Tomar do Geru      0    -1     39
# 7874            280760                  Umbaúba      0    -1     39
#
#                      nome_grupo
# 0        Trabalhadores da Saúde
# 1        Trabalhadores da Saúde
# 2        Trabalhadores da Saúde
# 3        Trabalhadores da Saúde
# 4        Trabalhadores da Saúde
# ...                         ...
# 7870  População de 12 a 14 anos
# 7871  População de 12 a 14 anos
# 7872  População de 12 a 14 anos
# 7873  População de 12 a 14 anos
# 7874  População de 12 a 14 anos
#
# [7875 rows x 6 columns]

# %% [markdown]
# ### Agrupando por Dose e Grupos

# %%
data_group_estado = data_group[['dose','grupo','nome_grupo','total']].groupby(by=['dose','grupo','nome_grupo']).sum()
data_group_estado.reset_index(inplace=True)
data_group_estado
# Out:
#      dose  grupo                                         nome_grupo  total
# 0      -1      1                             Trabalhadores da Saúde    883
# 1      -1      2  Pessoas com 60 anos ou mais e deficientes Inst...     89
# 2      -1      3                                      Índio Aldeado      0
# 3      -1      4                         Pessoas com 80 anos e mais     14
# 4      -1      5                            Pessoas de 70 a 79 anos     37
# ..    ...    ...                                                ...    ...
# 100     2     35                          População de 25 a 29 anos   8538
# 101     2     36                          População de 20 a 24 anos   3456
# 102     2     37                          População de 18 e 19 anos    537
# 103     2     38                          População de 15 a 17 anos     28
# 104     2     39                          População de 12 a 14 anos     24
#
# [105 rows x 4 columns]

# %%
data_group_estado.to_csv("output/data_vacinas_grupos_estado.csv", index=False)

# %%
data_group_municipio = data_group.groupby(by=['codigo_municipio','municipio','dose','grupo','nome_grupo']).sum()
data_group_municipio.reset_index(inplace=True)
data_group_municipio
# Out:
#       codigo_municipio                municipio  dose  grupo  \
# 0               280010  Amparo de São Francisco    -1      1
# 1               280010  Amparo de São Francisco    -1      2
# 2               280010  Amparo de São Francisco    -1      3
# 3               280010  Amparo de São Francisco    -1      4
# 4               280010  Amparo de São Francisco    -1      5
# ...                ...                      ...   ...    ...
# 7870            280760                  Umbaúba     2     35
# 7871            280760                  Umbaúba     2     36
# 7872            280760                  Umbaúba     2     37
# 7873            280760                  Umbaúba     2     38
# 7874            280760                  Umbaúba     2     39
#
#                                              nome_grupo  total
# 0                                Trabalhadores da Saúde      5
# 1     Pessoas com 60 anos ou mais e deficientes Inst...      0
# 2                                         Índio Aldeado      0
# 3                            Pessoas com 80 anos e mais      0
# 4                               Pessoas de 70 a 79 anos      0
# ...                                                 ...    ...
# 7870                          População de 25 a 29 anos    229
# 7871                          População de 20 a 24 anos     38
# 7872                          População de 18 e 19 anos      0
# 7873                          População de 15 a 17 anos      0
# 7874                          População de 12 a 14 anos      0
#
# [7875 rows x 6 columns]

# %%
data_group_municipio.to_csv("output/data_vacinas_grupos_municipios.csv", index=False)

# %%
data_group_pivot = data_group_estado.pivot_table(values='total', index=['grupo','nome_grupo'], columns='dose')
data_group_pivot.reset_index(inplace=True)
data_group_pivot.rename(columns={-1: 'dose_unica', 1: 'dose_1', 2: 'dose_2'}, inplace=True)
data_group_pivot
# Out:
# dose  grupo                                         nome_grupo  dose_unica  \
# 0         1                             Trabalhadores da Saúde         883
# 1         2  Pessoas com 60 anos ou mais e deficientes Inst...          89
# 2         3                                      Índio Aldeado           0
# 3         4                         Pessoas com 80 anos e mais          14
# 4         5                            Pessoas de 70 a 79 anos          37
# 5         6                            Pessoas de 60 a 69 anos         219
# 6         7                                    Situação de Rua         129
# 7         8                                        Quilombolas         179
# 8         9              Trabalhadores das forças de segurança          40
# 9        14                              Deficiente Permanente          79
# 10       15                                       Comorbidades         648
# 11       16                          Trabalhadores da Educação         458
# 12       17                 Trabalhadores do sistema prisional           1
# 13       18                              Privados de liberdade          17
# 14       19                  Trabalhadores do Transporte aéreo           1
# 15       20                    Trabalhadores da Limpeza Urbana          70
# 16       21               Trabalhadores do Transporte Coletivo          56
# 17       22                                      Caminhoneiros          89
# 18       23                          População de 55 a 59 anos       11857
# 19       24                 Trabalhadores da Educação Superior          14
# 20       25                    Trabalhadores da Zona Portuária           1
# 21       26                  Trabalhadores Industriais e Civil         459
# 22       27                          População de 50 a 54 anos        2396
# 23       28                          População de 45 a 49 anos        5479
# 24       29                          População de 40 a 44 anos       10794
# 25       30                                          Gestantes           0
# 26       31                                          Puerperas           3
# 27       32                          População de 35 a 39 anos        4757
# 28       33                          População de 30 a 34 anos         733
# 29       34                                          Lactantes           0
# 30       35                          População de 25 a 29 anos         349
# 31       36                          População de 20 a 24 anos          10
# 32       37                          População de 18 e 19 anos          91
# 33       38                          População de 15 a 17 anos           0
# 34       39                          População de 12 a 14 anos           0
#
# dose  dose_1  dose_2
# 0      77701   70623
# 1        935    1751
# 2        281     276
# 3      40768   38580
# 4      81814   87052
# 5     143669  137730
# 6        339     134
# 7      11616   10201
# 8       8789    6684
# 9       9957    4663
# 10    122494   61653
# 11     36763   23982
# 12       846     263
# 13      5304    1791
# 14       453     148
# 15      4393    2483
# 16      4037    1966
# 17      7127    3239
# 18     64137   44421
# 19      3938    1928
# 20       518     360
# 21     18473    6944
# 22     79901   36589
# 23     89375   24537
# 24     98409   17886
# 25     11686    3331
# 26      2541    1053
# 27    106698   14246
# 28    115597   17194
# 29      1816     374
# 30    119191    8538
# 31    125090    3456
# 32     51644     537
# 33     12147      28
# 34      6097      24

# %%
data_group_pivot.to_csv("output/data_vacinas_grupos_estado2.csv", index=False)

# %% [markdown]
# ## Vacinas Recebidas

# %%
def map_mounth(value):
    
    split_ = value.split("-")
    day = split_[0]
    mounth = split_[1]
    
    map_ = {
        'jan': '01',
        'fev': '02',
        'mar': '03',
        'abr': '04',
        'mai': '05',
        'jun': '06',
        'jul': '07',
        'ago': '08',
        'set': '09',
        'out': '10',
        'nov': '11',
        'dez': '12'
    }
    
    str_return = "2021-" + map_[mounth] + "-" + day
    
    return str_return

# %%
def map_vacinas(value):
    
    map_ = {
        'Coronavac': 'Butantan/CoronaVac',
        'AstraZeneca': 'Oxford/AstraZeneca/Fiocruz',
        'Astrazeneca': 'Oxford/AstraZeneca/Fiocruz',
        'Pfizer': 'Pfizer/BioNTech',
        'Janssen': 'Janssen',
        'Coronavac/monodose': 'Butantan/CoronaVac'
    }
    
    return map_[value]

# %%
vacinas_recebidas = pd.read_csv("data_insumos/vacinas_recebidas.csv", skiprows=2, names=['data','vacina','publico_alvo','total'], thousands='.')
vacinas_recebidas
# Out:
#        data       vacina                                       publico_alvo  \
# 0    09-set       Pfizer                       Destinado para primeira dose
# 1    09-set    Coronavac             Destinado para primeira e segunda dose
# 2    08-set       Pfizer             Destinado para primeira e segunda dose
# 3    06-set       Pfizer                        Destinado para segunda dose
# 4    05-set    Coronavac                        Destinado para segunda dose
# ..      ...          ...                                                ...
# 89  24-fev.  AstraZeneca           Trabalhadores saúde, idosos 80 a 89 anos
# 90  07-fev.    Coronavac           Trabalhadores saúde, idosos 90 anos mais
# 91  25-jan.    Coronavac                                Trabalhadores saúde
# 92  24-jan.  AstraZeneca                                Trabalhadores saúde
# 93  18-jan.    Coronavac  Trabalhadores saúde, idosos institucionalizado...
#
#     total
# 0   11700
# 1   19400
# 2   24570
# 3   15210
# 4   38600
# ..    ...
# 89  16500
# 90  23800
# 91   8800
# 92  19000
# 93  48880
#
# [94 rows x 4 columns]

# %%
vacinas_recebidas = pd.read_csv("data_insumos/vacinas_recebidas.csv", skiprows=2, names=['data','vacina','publico_alvo','total'], thousands='.')
vacinas_recebidas['data'] = vacinas_recebidas['data'].str.replace(".", "")
vacinas_recebidas['data'] = vacinas_recebidas['data'].apply(map_mounth)
vacinas_recebidas['data'] = pd.to_datetime(vacinas_recebidas['data'])
vacinas_recebidas['vacina'] = vacinas_recebidas['vacina'].apply(map_vacinas)
vacinas_recebidas.drop(columns=['publico_alvo'], inplace=True)
vacinas_recebidas
# Out:
#          data                      vacina  total
# 0  2021-09-09             Pfizer/BioNTech  11700
# 1  2021-09-09          Butantan/CoronaVac  19400
# 2  2021-09-08             Pfizer/BioNTech  24570
# 3  2021-09-06             Pfizer/BioNTech  15210
# 4  2021-09-05          Butantan/CoronaVac  38600
# ..        ...                         ...    ...
# 89 2021-02-24  Oxford/AstraZeneca/Fiocruz  16500
# 90 2021-02-07          Butantan/CoronaVac  23800
# 91 2021-01-25          Butantan/CoronaVac   8800
# 92 2021-01-24  Oxford/AstraZeneca/Fiocruz  19000
# 93 2021-01-18          Butantan/CoronaVac  48880
#
# [94 rows x 3 columns]

# %%
#vacinas_recebidas['mes'] = pd.DatetimeIndex(vacinas_recebidas['data']).month_name(locale='pt_BR')
vacinas_recebidas['mes_int'] = pd.DatetimeIndex(vacinas_recebidas['data']).month
vacinas_recebidas.sort_values(by=['data'], inplace=True)
vacinas_recebidas
# Out:
#          data                      vacina  total  mes_int
# 93 2021-01-18          Butantan/CoronaVac  48880        1
# 92 2021-01-24  Oxford/AstraZeneca/Fiocruz  19000        1
# 91 2021-01-25          Butantan/CoronaVac   8800        1
# 87 2021-02-03          Butantan/CoronaVac  26000        2
# 90 2021-02-07          Butantan/CoronaVac  23800        2
# ..        ...                         ...    ...      ...
# 4  2021-09-05          Butantan/CoronaVac  38600        9
# 3  2021-09-06             Pfizer/BioNTech  15210        9
# 2  2021-09-08             Pfizer/BioNTech  24570        9
# 1  2021-09-09          Butantan/CoronaVac  19400        9
# 0  2021-09-09             Pfizer/BioNTech  11700        9
#
# [94 rows x 4 columns]

# %%
vacinas_group = vacinas_recebidas.groupby(by=['mes_int','vacina'], sort=False).sum()
vacinas_group.reset_index(inplace=True)
vacinas_group
# Out:
#     mes_int                      vacina   total
# 0         1          Butantan/CoronaVac   57680
# 1         1  Oxford/AstraZeneca/Fiocruz   19000
# 2         2          Butantan/CoronaVac   58800
# 3         2  Oxford/AstraZeneca/Fiocruz   16500
# 4         3          Butantan/CoronaVac  126600
# 5         3  Oxford/AstraZeneca/Fiocruz   39650
# 6         4          Butantan/CoronaVac  121800
# 7         4  Oxford/AstraZeneca/Fiocruz  134250
# 8         5          Butantan/CoronaVac   47080
# 9         5             Pfizer/BioNTech   30420
# 10        5  Oxford/AstraZeneca/Fiocruz  277650
# 11        6  Oxford/AstraZeneca/Fiocruz  223250
# 12        6             Pfizer/BioNTech   83070
# 13        6          Butantan/CoronaVac   47400
# 14        6                     Janssen   16300
# 15        7             Pfizer/BioNTech  115830
# 16        7  Oxford/AstraZeneca/Fiocruz  139550
# 17        7                     Janssen   22400
# 18        7          Butantan/CoronaVac   83700
# 19        8          Butantan/CoronaVac  179730
# 20        8             Pfizer/BioNTech  359190
# 21        8                     Janssen    1050
# 22        8  Oxford/AstraZeneca/Fiocruz  152500
# 23        9             Pfizer/BioNTech   91260
# 24        9  Oxford/AstraZeneca/Fiocruz   16250
# 25        9          Butantan/CoronaVac   58000

# %%
vacinas_group = vacinas_group.pivot_table(values='total', index=['mes_int'], columns='vacina')
vacinas_group.fillna(0, inplace=True)
vacinas_group.reset_index(inplace=True)
vacinas_group = pd.melt(vacinas_group, id_vars=['mes_int'], value_name='total')
#vacinas_group.dropna(inplace=True)
vacinas_group['total'] = vacinas_group['total'].astype(int)
vacinas_group
# Out:
#     mes_int                      vacina   total
# 0         1          Butantan/CoronaVac   57680
# 1         2          Butantan/CoronaVac   58800
# 2         3          Butantan/CoronaVac  126600
# 3         4          Butantan/CoronaVac  121800
# 4         5          Butantan/CoronaVac   47080
# 5         6          Butantan/CoronaVac   47400
# 6         7          Butantan/CoronaVac   83700
# 7         8          Butantan/CoronaVac  179730
# 8         9          Butantan/CoronaVac   58000
# 9         1                     Janssen       0
# 10        2                     Janssen       0
# 11        3                     Janssen       0
# 12        4                     Janssen       0
# 13        5                     Janssen       0
# 14        6                     Janssen   16300
# 15        7                     Janssen   22400
# 16        8                     Janssen    1050
# 17        9                     Janssen       0
# 18        1  Oxford/AstraZeneca/Fiocruz   19000
# 19        2  Oxford/AstraZeneca/Fiocruz   16500
# 20        3  Oxford/AstraZeneca/Fiocruz   39650
# 21        4  Oxford/AstraZeneca/Fiocruz  134250
# 22        5  Oxford/AstraZeneca/Fiocruz  277650
# 23        6  Oxford/AstraZeneca/Fiocruz  223250
# 24        7  Oxford/AstraZeneca/Fiocruz  139550
# 25        8  Oxford/AstraZeneca/Fiocruz  152500
# 26        9  Oxford/AstraZeneca/Fiocruz   16250
# 27        1             Pfizer/BioNTech       0
# 28        2             Pfizer/BioNTech       0
# 29        3             Pfizer/BioNTech       0
# 30        4             Pfizer/BioNTech       0
# 31        5             Pfizer/BioNTech   30420
# 32        6             Pfizer/BioNTech   83070
# 33        7             Pfizer/BioNTech  115830
# 34        8             Pfizer/BioNTech  359190
# 35        9             Pfizer/BioNTech   91260

# %%
vacinas_group['mes'] = pd.to_datetime(vacinas_group.mes_int, format='%m').dt.month_name(locale='pt_BR')
vacinas_group.sort_values(by=['mes_int','vacina'], inplace=True)
vacinas_group
# Out:
#     mes_int                      vacina   total        mes
# 0         1          Butantan/CoronaVac   57680    Janeiro
# 9         1                     Janssen       0    Janeiro
# 18        1  Oxford/AstraZeneca/Fiocruz   19000    Janeiro
# 27        1             Pfizer/BioNTech       0    Janeiro
# 1         2          Butantan/CoronaVac   58800  Fevereiro
# 10        2                     Janssen       0  Fevereiro
# 19        2  Oxford/AstraZeneca/Fiocruz   16500  Fevereiro
# 28        2             Pfizer/BioNTech       0  Fevereiro
# 2         3          Butantan/CoronaVac  126600      Março
# 11        3                     Janssen       0      Março
# 20        3  Oxford/AstraZeneca/Fiocruz   39650      Março
# 29        3             Pfizer/BioNTech       0      Março
# 3         4          Butantan/CoronaVac  121800      Abril
# 12        4                     Janssen       0      Abril
# 21        4  Oxford/AstraZeneca/Fiocruz  134250      Abril
# 30        4             Pfizer/BioNTech       0      Abril
# 4         5          Butantan/CoronaVac   47080       Maio
# 13        5                     Janssen       0       Maio
# 22        5  Oxford/AstraZeneca/Fiocruz  277650       Maio
# 31        5             Pfizer/BioNTech   30420       Maio
# 5         6          Butantan/CoronaVac   47400      Junho
# 14        6                     Janssen   16300      Junho
# 23        6  Oxford/AstraZeneca/Fiocruz  223250      Junho
# 32        6             Pfizer/BioNTech   83070      Junho
# 6         7          Butantan/CoronaVac   83700      Julho
# 15        7                     Janssen   22400      Julho
# 24        7  Oxford/AstraZeneca/Fiocruz  139550      Julho
# 33        7             Pfizer/BioNTech  115830      Julho
# 7         8          Butantan/CoronaVac  179730     Agosto
# 16        8                     Janssen    1050     Agosto
# 25        8  Oxford/AstraZeneca/Fiocruz  152500     Agosto
# 34        8             Pfizer/BioNTech  359190     Agosto
# 8         9          Butantan/CoronaVac   58000   Setembro
# 17        9                     Janssen       0   Setembro
# 26        9  Oxford/AstraZeneca/Fiocruz   16250   Setembro
# 35        9             Pfizer/BioNTech   91260   Setembro

# %%
vacinas_group[['mes','mes_int','vacina','total']].to_csv("output/total_vacinas_recebidas.csv", index=False)
