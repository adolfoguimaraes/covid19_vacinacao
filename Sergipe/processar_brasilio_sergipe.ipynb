# %%
import pandas as pd
import numpy as np

# %%
caso_full = pd.read_csv('data_general/caso_full.csv')

# %%
caso_full.columns
# Out:
# Index(['city', 'city_ibge_code', 'date', 'epidemiological_week',
#        'estimated_population', 'estimated_population_2019', 'is_last',
#        'is_repeated', 'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'last_available_date',
#        'last_available_death_rate', 'last_available_deaths', 'order_for_place',
#        'place_type', 'state', 'new_confirmed', 'new_deaths'],
#       dtype='object')

# %%
caso_full_sergipe = caso_full.query('state == "SE" and city.isnull()', engine='python')
caso_full_sergipe
# Out:
#         city  city_ibge_code        date  epidemiological_week  \
# 2025006  NaN            28.0  2020-03-14                202011
# 2025008  NaN            28.0  2020-03-15                202012
# 2025010  NaN            28.0  2020-03-16                202012
# 2025012  NaN            28.0  2020-03-17                202012
# 2025015  NaN            28.0  2020-03-18                202012
# ...      ...             ...         ...                   ...
# 2057939  NaN            28.0  2021-07-07                202127
# 2058015  NaN            28.0  2021-07-08                202127
# 2058091  NaN            28.0  2021-07-09                202127
# 2058167  NaN            28.0  2021-07-10                202127
# 2058243  NaN            28.0  2021-07-11                202128
#
#          estimated_population  estimated_population_2019  is_last  \
# 2025006             2318822.0                  2298696.0    False
# 2025008             2318822.0                  2298696.0    False
# 2025010             2318822.0                  2298696.0    False
# 2025012             2318822.0                  2298696.0    False
# 2025015             2318822.0                  2298696.0    False
# ...                       ...                        ...      ...
# 2057939             2318822.0                  2298696.0    False
# 2058015             2318822.0                  2298696.0    False
# 2058091             2318822.0                  2298696.0    False
# 2058167             2318822.0                  2298696.0    False
# 2058243             2318822.0                  2298696.0     True
#
#          is_repeated  last_available_confirmed  \
# 2025006        False                         1
# 2025008         True                         1
# 2025010        False                         5
# 2025012         True                         5
# 2025015        False                         6
# ...              ...                       ...
# 2057939        False                    267107
# 2058015        False                    267596
# 2058091        False                    268229
# 2058167        False                    268504
# 2058243        False                    268803
#
#          last_available_confirmed_per_100k_inhabitants last_available_date  \
# 2025006                                        0.04313          2020-03-14
# 2025008                                        0.04313          2020-03-14
# 2025010                                        0.21563          2020-03-16
# 2025012                                        0.21563          2020-03-16
# 2025015                                        0.25875          2020-03-18
# ...                                                ...                 ...
# 2057939                                    11519.08167          2021-07-07
# 2058015                                    11540.16997          2021-07-08
# 2058091                                    11567.46831          2021-07-09
# 2058167                                    11579.32778          2021-07-10
# 2058243                                    11592.22226          2021-07-11
#
#          last_available_death_rate  last_available_deaths  order_for_place  \
# 2025006                     0.0000                      0                1
# 2025008                     0.0000                      0                2
# 2025010                     0.0000                      0                3
# 2025012                     0.0000                      0                4
# 2025015                     0.0000                      0                5
# ...                            ...                    ...              ...
# 2057939                     0.0216                   5779              481
# 2058015                     0.0216                   5786              482
# 2058091                     0.0216                   5794              483
# 2058167                     0.0216                   5802              484
# 2058243                     0.0216                   5811              485
#
#         place_type state  new_confirmed  new_deaths
# 2025006      state    SE              1           0
# 2025008      state    SE              0           0
# 2025010      state    SE              4           0
# 2025012      state    SE              0           0
# 2025015      state    SE              1           0
# ...            ...   ...            ...         ...
# 2057939      state    SE            517           6
# 2058015      state    SE            489           7
# 2058091      state    SE            633           8
# 2058167      state    SE            275           8
# 2058243      state    SE            299           9
#
# [485 rows x 18 columns]

# %%
caso_full_selected = caso_full_sergipe[['date','last_available_confirmed','last_available_deaths','new_confirmed','new_deaths']]
caso_full_selected
# Out:
#                date  last_available_confirmed  last_available_deaths  \
# 2025006  2020-03-14                         1                      0
# 2025008  2020-03-15                         1                      0
# 2025010  2020-03-16                         5                      0
# 2025012  2020-03-17                         5                      0
# 2025015  2020-03-18                         6                      0
# ...             ...                       ...                    ...
# 2057939  2021-07-07                    267107                   5779
# 2058015  2021-07-08                    267596                   5786
# 2058091  2021-07-09                    268229                   5794
# 2058167  2021-07-10                    268504                   5802
# 2058243  2021-07-11                    268803                   5811
#
#          new_confirmed  new_deaths
# 2025006              1           0
# 2025008              0           0
# 2025010              4           0
# 2025012              0           0
# 2025015              1           0
# ...                ...         ...
# 2057939            517           6
# 2058015            489           7
# 2058091            633           8
# 2058167            275           8
# 2058243            299           9
#
# [485 rows x 5 columns]

# %%
caso_full_selected['mean_confirmed'] = caso_full_selected['new_confirmed'].rolling(window=7).mean()
caso_full_selected['mean_deaths'] = caso_full_selected['new_deaths'].rolling(window=7).mean()
# Out:
# <ipython-input-6-de32b8ad372d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   caso_full_selected['mean_confirmed'] = caso_full_selected['new_confirmed'].rolling(window=7).mean()
# <ipython-input-6-de32b8ad372d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   caso_full_selected['mean_deaths'] = caso_full_selected['new_deaths'].rolling(window=7).mean()

# %%
caso_full.replace([np.inf, -np.inf], np.nan, inplace=True)
caso_full_selected = caso_full_selected.fillna(0)
caso_full_selected
# Out:
#                date  last_available_confirmed  last_available_deaths  \
# 2025006  2020-03-14                         1                      0
# 2025008  2020-03-15                         1                      0
# 2025010  2020-03-16                         5                      0
# 2025012  2020-03-17                         5                      0
# 2025015  2020-03-18                         6                      0
# ...             ...                       ...                    ...
# 2057939  2021-07-07                    267107                   5779
# 2058015  2021-07-08                    267596                   5786
# 2058091  2021-07-09                    268229                   5794
# 2058167  2021-07-10                    268504                   5802
# 2058243  2021-07-11                    268803                   5811
#
#          new_confirmed  new_deaths  mean_confirmed  mean_deaths
# 2025006              1           0        0.000000     0.000000
# 2025008              0           0        0.000000     0.000000
# 2025010              4           0        0.000000     0.000000
# 2025012              0           0        0.000000     0.000000
# 2025015              1           0        0.000000     0.000000
# ...                ...         ...             ...          ...
# 2057939            517           6      513.571429    11.571429
# 2058015            489           7      483.285714    10.285714
# 2058091            633           8      490.142857     8.857143
# 2058167            275           8      460.857143     8.428571
# 2058243            299           9      411.142857     7.857143
#
# [485 rows x 7 columns]

# %%
caso_full_selected['pct_change_confirmed'] = caso_full_selected['mean_confirmed'].pct_change(14)
caso_full_selected['pct_change_deaths'] = caso_full_selected['mean_deaths'].pct_change(14)
caso_full.replace([np.inf, -np.inf], np.nan, inplace=True)
caso_full_selected = caso_full_selected.fillna(0)
caso_full_selected
# Out:
#                date  last_available_confirmed  last_available_deaths  \
# 2025006  2020-03-14                         1                      0
# 2025008  2020-03-15                         1                      0
# 2025010  2020-03-16                         5                      0
# 2025012  2020-03-17                         5                      0
# 2025015  2020-03-18                         6                      0
# ...             ...                       ...                    ...
# 2057939  2021-07-07                    267107                   5779
# 2058015  2021-07-08                    267596                   5786
# 2058091  2021-07-09                    268229                   5794
# 2058167  2021-07-10                    268504                   5802
# 2058243  2021-07-11                    268803                   5811
#
#          new_confirmed  new_deaths  mean_confirmed  mean_deaths  \
# 2025006              1           0        0.000000     0.000000
# 2025008              0           0        0.000000     0.000000
# 2025010              4           0        0.000000     0.000000
# 2025012              0           0        0.000000     0.000000
# 2025015              1           0        0.000000     0.000000
# ...                ...         ...             ...          ...
# 2057939            517           6      513.571429    11.571429
# 2058015            489           7      483.285714    10.285714
# 2058091            633           8      490.142857     8.857143
# 2058167            275           8      460.857143     8.428571
# 2058243            299           9      411.142857     7.857143
#
#          pct_change_confirmed  pct_change_deaths
# 2025006              0.000000           0.000000
# 2025008              0.000000           0.000000
# 2025010              0.000000           0.000000
# 2025012              0.000000           0.000000
# 2025015              0.000000           0.000000
# ...                       ...                ...
# 2057939             -0.339519          -0.463576
# 2058015             -0.377782          -0.482014
# 2058091             -0.345853          -0.526718
# 2058167             -0.359539          -0.504202
# 2058243             -0.428968          -0.471154
#
# [485 rows x 9 columns]

# %%
caso_full_selected.reset_index(inplace=True,drop=True)
caso_full_selected
# Out:
#            date  last_available_confirmed  last_available_deaths  \
# 0    2020-03-14                         1                      0
# 1    2020-03-15                         1                      0
# 2    2020-03-16                         5                      0
# 3    2020-03-17                         5                      0
# 4    2020-03-18                         6                      0
# ..          ...                       ...                    ...
# 480  2021-07-07                    267107                   5779
# 481  2021-07-08                    267596                   5786
# 482  2021-07-09                    268229                   5794
# 483  2021-07-10                    268504                   5802
# 484  2021-07-11                    268803                   5811
#
#      new_confirmed  new_deaths  mean_confirmed  mean_deaths  \
# 0                1           0        0.000000     0.000000
# 1                0           0        0.000000     0.000000
# 2                4           0        0.000000     0.000000
# 3                0           0        0.000000     0.000000
# 4                1           0        0.000000     0.000000
# ..             ...         ...             ...          ...
# 480            517           6      513.571429    11.571429
# 481            489           7      483.285714    10.285714
# 482            633           8      490.142857     8.857143
# 483            275           8      460.857143     8.428571
# 484            299           9      411.142857     7.857143
#
#      pct_change_confirmed  pct_change_deaths
# 0                0.000000           0.000000
# 1                0.000000           0.000000
# 2                0.000000           0.000000
# 3                0.000000           0.000000
# 4                0.000000           0.000000
# ..                    ...                ...
# 480             -0.339519          -0.463576
# 481             -0.377782          -0.482014
# 482             -0.345853          -0.526718
# 483             -0.359539          -0.504202
# 484             -0.428968          -0.471154
#
# [485 rows x 9 columns]

# %%
caso_full_selected.to_csv("output/sergipe_historico.csv", index=False)

# %%
caso_full_selected.columns
# Out:
# Index(['date', 'last_available_confirmed', 'last_available_deaths',
#        'new_confirmed', 'new_deaths', 'mean_confirmed', 'mean_deaths',
#        'pct_change_confirmed', 'pct_change_deaths'],
#       dtype='object')
