# %% [markdown]
# # Microdados de Vacinação - OpenDataSUS
#
# Este documento possui o código que estou utilizando para processar o arquivo de microdados da vacinação disponibilizado pelo SUS. As informações sobre a base pode ser encontrada [neste link](https://opendatasus.saude.gov.br/dataset/covid-19-vacinacao). Existem duas formas de acessar os dados: (1) a partir do arquivo CSV, que atualmente possui mais de 1GB de dados ou (2) através de uma API Elasticsearch.
#
# Estou usando uma versão disponibilizada pelo [Brasil.io](brasil.io). Detalhes deste documento podem ser encontrados nesse status do twitter: https://twitter.com/brasil_io/status/1361080270791864321. Os dados processados pelo brasil.io estão mais limpos, consistentes e com alterações que permitiram gerar um arquivo menor. O processamento a seguir vai ser feito em cima deste arquivo que pode ser acessado a partir do status do brasil.io. O arquivo não está disponível neste repositório.
#
# Minha proposta neste documento é mostrar como podemos usar o [pandas](https://pandas.pydata.org/) para olhar um pouco mais para esses dados. Vale ressaltar que estes dados contém informações do Brasil inteiro e que inconsistências podem existir por diversos motivos como erros na hora da coletar e da alimentação dos dados.
#
# O compartilhamento destes dados são de extrema importância para que todos possam ter accesso às informações completas dos registros da vacinação. Até o dia 12/02 os dados ainda estavam incompletos totalizando pouco mais de 2,1 milhões de vacinados. Outras fontes informavam nesta mesma data mais de 4 milhões de vacinados.
#
# A medida que o arquivo for sendo atualizado, esse doumento também será.

# %%
# Bibliotecas utilizadas 

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carregando os dados a partir do arquivo microdados_vacinacao.csv

data_microdados = pd.read_csv("data/microdados_vacinacao.csv")

# %%
data_microdados.head()
# Out:
#                          documento_uuid                         paciente_uuid  \
# 0  cff59c9f-7059-5daa-8fae-933fffa3ae33  331b2d7a-8074-559d-8700-a30bdbf6e364
# 1  bf443981-541a-5f04-b1a6-3b25ca250ea0  76122550-1f8d-5f36-b340-6a098cbe4b41
# 2  e0305612-79ae-5960-af32-9d6b54d5a74a  823ec249-b52d-576b-ae2a-84dbc9a6f451
# 3  14bf0206-b358-524a-a378-a3f56615d4c8  51581b55-f97e-5dab-b8a5-f17ca1555f83
# 4  a1e37795-7652-5267-9150-88bbf6d480c9  fee27694-96ef-5e25-8d56-9de742e240a5
#
#    paciente_idade paciente_sexo_biologico  paciente_codigo_etnia  \
# 0            82.0                       F                    5.0
# 1            35.0                       F                    3.0
# 2            78.0                       F                    4.0
# 3            87.0                       M                    1.0
# 4            30.0                       F                    4.0
#
#   paciente_etnia  paciente_codigo_ibge_municipio  paciente_codigo_pais  \
# 0       Indígena                       2911402.0                  10.0
# 1          Parda                       2804409.0                  10.0
# 2        Amarela                       2307304.0                  10.0
# 3         Branca                       3304557.0                  10.0
# 4        Amarela                       3162500.0                  10.0
#
#   paciente_municipio paciente_pais  ... paciente_codigo_subgrupo  \
# 0             Glória        Brasil  ...                      701
# 1           Neópolis        Brasil  ...                      926
# 2  Juazeiro do Norte        Brasil  ...                      204
# 3     Rio de Janeiro        Brasil  ...                      205
# 4   São João del Rei        Brasil  ...                      923
#
#                      paciente_subgrupo paciente_codigo_grupo  \
# 0  Povos indígenas em terras indígenas                   7.0
# 1                               Outros                   9.0
# 2              Pessoas de 75 a 79 anos                   2.0
# 3           Pessoas de 80 anos ou mais                   2.0
# 4                Técnico de Enfermagem                   9.0
#
#            paciente_grupo vacina_lote data_aplicacao  numero_dose  \
# 0         Povos Indígenas   202010027     2021-01-20            1
# 1  Trabalhadores de Saúde      200280     2021-02-09            1
# 2            Faixa Etária    4120Z005     2021-02-04            1
# 3            Faixa Etária   202009015     2021-02-10            1
# 4  Trabalhadores de Saúde   202010038     2021-01-22            1
#
#   codigo_vacina                               vacina  sistema_origem
# 0            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 1            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 2            85         Vacina Covid-19 - Covishield        Novo PNI
# 3            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 4            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
#
# [5 rows x 29 columns]

# %%
data_microdados.columns
# Out:
# Index(['documento_uuid', 'paciente_uuid', 'paciente_idade',
#        'paciente_sexo_biologico', 'paciente_codigo_etnia', 'paciente_etnia',
#        'paciente_codigo_ibge_municipio', 'paciente_codigo_pais',
#        'paciente_municipio', 'paciente_pais', 'paciente_unidade_federativa',
#        'paciente_cep', 'paciente_nacionalidade', 'estabelecimento_codigo_cnes',
#        'estabelecimento_razao_social', 'estabelecimento',
#        'estabelecimento_codigo_ibge_municipio', 'estabelecimento_municipio',
#        'estabelecimento_unidade_federativa', 'paciente_codigo_subgrupo',
#        'paciente_subgrupo', 'paciente_codigo_grupo', 'paciente_grupo',
#        'vacina_lote', 'data_aplicacao', 'numero_dose', 'codigo_vacina',
#        'vacina', 'sistema_origem'],
#       dtype='object')

# %%
data_microdados.dtypes
# Out:
# documento_uuid                            object
# paciente_uuid                             object
# paciente_idade                           float64
# paciente_sexo_biologico                   object
# paciente_codigo_etnia                    float64
# paciente_etnia                            object
# paciente_codigo_ibge_municipio           float64
# paciente_codigo_pais                     float64
# paciente_municipio                        object
# paciente_pais                             object
# paciente_unidade_federativa               object
# paciente_cep                             float64
# paciente_nacionalidade                    object
# estabelecimento_codigo_cnes                int64
# estabelecimento_razao_social              object
# estabelecimento                           object
# estabelecimento_codigo_ibge_municipio    float64
# estabelecimento_municipio                 object
# estabelecimento_unidade_federativa        object
# paciente_codigo_subgrupo                   int64
# paciente_subgrupo                         object
# paciente_codigo_grupo                    float64
# paciente_grupo                            object
# vacina_lote                               object
# data_aplicacao                            object
# numero_dose                                int64
# codigo_vacina                              int64
# vacina                                    object
# sistema_origem                            object
# dtype: object

# %%
data_microdados.shape
# Out:
# (2188463, 29)

# %% [markdown]
# ## Olhando mais para os dados
#
# Nesse tipo de dado, que é gerado a partir de informações coletadas no Brasil inteiro por diversos municípios, pode acontecer de ter algumas inconsistências. Muitas das vezes essas inconsistências se dar por conta de erros no processo de digitação e coleta destas informações. Mesmo sem ter como saber a origem do problema, vale a pena verificar algumas possíveis inconsistências para um eventual pré-processamento da base e utilização da mesma para construção de dashboards.
#
# ### Datas
#
# A primeira coisa que vou fazer é olhar a quantidade de registros de vacinação por dia.

# %%
data_microdados.groupby(by=['data_aplicacao','numero_dose']).count()[['paciente_uuid']]
# Out:
#                             paciente_uuid
# data_aplicacao numero_dose
# 2020-12-20     1                        1
# 2020-12-28     1                        2
# 2020-12-29     1                        1
# 2021-01-01     1                        2
# 2021-01-03     1                        1
# 2021-01-04     1                        1
# 2021-01-15     1                        1
# 2021-01-16     1                        1
# 2021-01-17     1                       12
# 2021-01-18     1                      467
# 2021-01-19     1                    36225
#                2                        6
# 2021-01-20     1                   223038
#                2                       82
# 2021-01-21     1                   207341
#                2                       64
# 2021-01-22     1                   160630
#                2                       39
# 2021-01-23     1                    36153
#                2                        9
# 2021-01-24     1                    12755
#                2                        3
# 2021-01-25     1                   105222
#                2                       37
# 2021-01-26     1                   126024
#                2                       52
# 2021-01-27     1                   144307
#                2                       67
# 2021-01-28     1                   140960
#                2                       88
# 2021-01-29     1                   114139
#                2                       69
# 2021-01-30     1                    22966
#                2                       11
# 2021-01-31     1                     8481
#                2                        2
# 2021-02-01     1                   106541
#                2                      107
# 2021-02-02     1                   113382
#                2                     1646
# 2021-02-03     1                   106045
#                2                     5888
# 2021-02-04     1                    89037
#                2                    12161
# 2021-02-05     1                    74527
#                2                    12846
# 2021-02-06     1                    20675
#                2                     1063
# 2021-02-07     1                     4555
#                2                      301
# 2021-02-08     1                    48099
#                2                    13403
# 2021-02-09     1                    58469
#                2                    12742
# 2021-02-10     1                    71313
#                2                    21069
# 2021-02-11     1                    48840
#                2                    15271
# 2021-02-12     1                     7395
#                2                     3822

# %% [markdown]
# Existem registros anteriores à data oficial de início da vacinação. Vamos ver quantos registros de vacinação antes do dia 17/01 quando a primeira dose da vacina foi aplicada: https://noticias.uol.com.br/saude/ultimas-noticias/redacao/2021/01/17/enfermeira-de-sp-negra-moradora-de-itaquera-e-1-vacinada-no-brasil.htm.

# %%
data_microdados[data_microdados['data_aplicacao'] < '2021-01-17'].groupby(by=['data_aplicacao','numero_dose']).count()[['paciente_uuid']]
# Out:
#                             paciente_uuid
# data_aplicacao numero_dose
# 2020-12-20     1                        1
# 2020-12-28     1                        2
# 2020-12-29     1                        1
# 2021-01-01     1                        2
# 2021-01-03     1                        1
# 2021-01-04     1                        1
# 2021-01-15     1                        1
# 2021-01-16     1                        1

# %% [markdown]
# Observe que no total são apenas 11 registros com datas anteriores à 17/01.

# %% [markdown]
# ### Idade
#
# Uma outra verificação é em relação a idade de quem recebeu as doses. Para isso vamos olhar o quantitativo no campo `paciente_idade_grupo` que é criado a partir do campo original `paciente_idade`. O campo `paciente_idade_grupo` discretiza os dados em faixas faixas hetárias. Foi utilizada a seguinte classificação de idades: Criança (0-12 anos), adolescente (13-18 anos), adulto (19-59 anos) e idoso (acima de 60 anos).

# %%
data_microdados['paciente_idade_grupo'] = pd.cut(data_microdados['paciente_idade'],bins=[0,13,19,60,float("inf")],right=False,labels=['criança','adolescente','adulto','idoso'])
data_microdados[['paciente_idade_grupo']].value_counts()
# Out:
# paciente_idade_grupo
# adulto                  1648916
# idoso                    530916
# adolescente                8494
# criança                     136
# dtype: int64

# %% [markdown]
# Somando o quantitativo de **crianças** e **adolescentes** tempos no total 8630 registros de pessoas menores que 17 anos que receberam a vacina. Sabendo que a aplicação da vacina está sendo em grupos prioritários que não incluem crianças e adolescentes, esses dados podem ser resultado de alguma inconsistência. Vamos ver esse quantitativo por idade.

# %%
data_microdados[data_microdados['paciente_idade'] < 18].groupby(by='paciente_idade').count()[['paciente_uuid']]
# Out:
#                 paciente_uuid
# paciente_idade
# 0.0                        16
# 1.0                         9
# 2.0                         7
# 3.0                         8
# 4.0                        12
# 5.0                         6
# 6.0                         8
# 7.0                        11
# 8.0                         9
# 9.0                        10
# 10.0                       12
# 11.0                        7
# 12.0                       21
# 13.0                       16
# 14.0                       16
# 15.0                       40
# 16.0                      135
# 17.0                      546

# %% [markdown]
# Vamos relacionar esses dados com o campo `paciente_subgrupo`:

# %%
temp_data = data_microdados[data_microdados['paciente_idade'] < 18].groupby(by=['paciente_idade','paciente_subgrupo']).count()[['paciente_uuid']]
initial_age = 0
print('Idade 0')
for index, row in temp_data.iterrows():
        if index[0] != initial_age:
            print()
            print('Idade %i' % index[0])
            initial_age = index[0]
        print(' %i %s' % (row['paciente_uuid'], index[1]))
# Out:
# Idade 0
#  2 Assistente Social
#  5 Outros
#  1 Pessoal da Limpeza
#  1 Pessoas de 80 anos ou mais
#  6 Povos indígenas em terras indígenas
#  1 Técnico de Enfermagem
#
# Idade 1
#  2 Enfermeiro(a)
#  1 Outros
#  1 Pessoas de 60 nos ou mais Institucionalizadas
#  1 Pessoas de 80 anos ou mais
#  3 Povos indígenas em terras indígenas
#  1 Técnico de Enfermagem
#
# Idade 2
#  1 Cuidador de Idosos
#  2 Enfermeiro(a)
#  1 Outros
#  1 Pessoas de 80 anos ou mais
#  1 Povos indígenas em terras indígenas
#  1 Recepcionista
#
# Idade 3
#  1 Médico
#  2 Outros
#  1 Pessoas de 75 a 79 anos
#  3 Povos indígenas em terras indígenas
#  1 Segurança
#
# Idade 4
#  1 Enfermeiro(a)
#  1 Fisioterapeutas
#  1 Fonoaudiólogo
#  2 Médico
#  2 Outros
#  1 Pessoas de 80 anos ou mais
#  1 Povos indígenas em terras indígenas
#  1 Profissionais de Educação Física
#  1 Recepcionista
#  1 Técnico de Enfermagem
#
# Idade 5
#  1 Motorista de Ambulância
#  1 Pessoal da Limpeza
#  3 Povos indígenas em terras indígenas
#  1 Técnico de Enfermagem
#
# Idade 6
#  1 Enfermeiro(a)
#  3 Outros
#  3 Povos indígenas em terras indígenas
#  1 Recepcionista
#
# Idade 7
#  1 Assistente Social
#  2 Outros
#  1 Pessoal da Limpeza
#  6 Povos indígenas em terras indígenas
#  1 Técnico de Enfermagem
#
# Idade 8
#  2 Fisioterapeutas
#  1 Outros
#  3 Povos indígenas em terras indígenas
#  3 Técnico de Enfermagem
#
# Idade 9
#  1 Motorista de Ambulância
#  1 Odontologista
#  1 Outros
#  1 Pessoal da Limpeza
#  1 Pessoas de 60 nos ou mais Institucionalizadas
#  2 Pessoas de 80 anos ou mais
#  3 Povos indígenas em terras indígenas
#
# Idade 10
#  1 Motorista de Ambulância
#  1 Médico
#  5 Outros
#  1 Pessoal da Limpeza
#  1 Pessoas de 80 anos ou mais
#  2 Povos indígenas em terras indígenas
#  1 Recepcionista
#
# Idade 11
#  1 Enfermeiro(a)
#  1 Outros
#  1 Pessoal da Limpeza
#  2 Povos indígenas em terras indígenas
#  1 Recepcionista
#  1 Técnico de Enfermagem
#
# Idade 12
#  2 Enfermeiro(a)
#  1 Farmacêutico
#  6 Outros
#  2 Pessoas de 80 anos ou mais
#  8 Povos indígenas em terras indígenas
#  1 Recepcionista
#  1 Segurança
#
# Idade 13
#  1 Enfermeiro(a)
#  1 Outros
#  2 Pessoas de 80 anos ou mais
#  10 Povos indígenas em terras indígenas
#  2 Técnico de Enfermagem
#
# Idade 14
#  1 Funcionário do Sistema Funerário c/ cadáveres potencialmente contaminados
#  5 Outros
#  1 Pessoas com Deficiência Institucionalizadas
#  1 Pessoas com Deficiências Permanente Grave
#  1 Pessoas de 60 a 64 anos
#  7 Povos indígenas em terras indígenas
#
# Idade 15
#  1 Auxiliar de Enfermagem
#  2 Cuidador de Idosos
#  1 Enfermeiro(a)
#  1 Médico
#  12 Outros
#  2 Pessoas de 60 nos ou mais Institucionalizadas
#  1 Pessoas de 80 anos ou mais
#  15 Povos indígenas em terras indígenas
#  2 Recepcionista
#  2 Técnico de Enfermagem
#  1 Técnico de Odontologia
#
# Idade 16
#  1 Cozinheiro e Auxiliares
#  1 Cuidador de Idosos
#  1 Doença Renal
#  3 Enfermeiro(a)
#  7 Estudante
#  1 Fisioterapeutas
#  3 Funcionário do Sistema Funerário c/ cadáveres potencialmente contaminados
#  1 Médico
#  1 Odontologista
#  59 Outros
#  3 Pessoal da Limpeza
#  4 Pessoas de 60 nos ou mais Institucionalizadas
#  2 Pessoas de 80 anos ou mais
#  19 Povos indígenas em terras indígenas
#  24 Recepcionista
#  1 Técnico de Enfermagem
#  4 Técnico de Odontologia
#
# Idade 17
#  2 Auxiliar de Enfermagem
#  2 Auxiliar de Veterinário
#  1 Cozinheiro e Auxiliares
#  14 Cuidador de Idosos
#  1 Doença Renal
#  2 Enfermeiro(a)
#  1 Ensino Básico
#  1 Ensino Superior
#  26 Estudante
#  1 Farmacêutico
#  2 Fisioterapeutas
#  4 Funcionário do Sistema Funerário c/ cadáveres potencialmente contaminados
#  2 Motorista de Ambulância
#  1 Médico
#  192 Outros
#  5 Pessoal da Limpeza
#  5 Pessoas com Deficiência Institucionalizadas
#  1 Pessoas com Deficiências Permanente Grave
#  3 Pessoas de 60 nos ou mais Institucionalizadas
#  2 Pessoas de 80 anos ou mais
#  130 Povos indígenas em terras indígenas
#  114 Recepcionista
#  2 Segurança
#  18 Técnico de Enfermagem
#  14 Técnico de Odontologia

# %% [markdown]
# Veja que pelos dados temos médicos, enfermeiros, motoristas com idades inferiores à 18 anos.

# %% [markdown]
# ### Recebimento das doses

# %% [markdown]
# O campo `paciente_id` identifica unicamente cada uma das pessoas que receberam a vacina. Com essa informação é possível fazer algumas verificações a respeito da duplicidade de informação. Vamos dar uma olhada nisso em vários aspectos.
#
# Primeiro vamos ver se existe dados duplicados entre os pacientes que receberam a primeira dose.

# %%
all_dose1 = data_microdados[data_microdados['numero_dose'] == 1]

# %% [markdown]
# Rodando o código a seguir, é possível ver que existem pouco mais de 21000 registros duplicados.

# %%
all_dose1[all_dose1[['paciente_uuid']].duplicated()]
# Out:
#                                documento_uuid  \
# 5664     be831f50-4953-527b-bdbd-6a1472843562
# 10900    a5b58595-4c9a-5f8c-a004-36701cfd40dc
# 20824    092077d0-19c5-589f-89da-429e88111bd2
# 21360    36cd25fb-dea0-5442-8f7e-dcc37482ee3d
# 22086    a24bce1d-e89b-5db2-9907-a277d36f3caf
# ...                                       ...
# 2188117  d3f79941-0e0e-544d-a902-d83a7e512268
# 2188147  7b5a753f-8095-5614-96fa-9d832acc4182
# 2188217  0238508f-851f-539c-aaff-571cfcb6484b
# 2188365  66612a9f-7098-58da-b530-0d033176ba35
# 2188447  bfa03b02-6329-508c-8a47-b016f670b160
#
#                                 paciente_uuid  paciente_idade  \
# 5664     1ab44d11-df4a-5751-b7e0-6bf897cc6a14            37.0
# 10900    f592871c-5654-5271-aabb-95f9cb246afb            34.0
# 20824    93a55089-8271-5f60-93cc-99d850609f6e            39.0
# 21360    b542e3fd-43ea-539b-8c08-45fcc6e0631b            24.0
# 22086    c5ae0cc2-8ac6-54a1-b704-751f869b3fea            55.0
# ...                                       ...             ...
# 2188117  f0a2e3fa-c201-543d-8c30-f192b67d5d39            50.0
# 2188147  919cba6c-311b-573f-ac66-f2162bcf6cd4            88.0
# 2188217  285deaa8-1a72-5202-b588-847f7bfd2340            25.0
# 2188365  cf4a305e-1f66-544a-8373-4822ec47b491            22.0
# 2188447  ce88a8a9-5a32-52ef-a3a8-b5e6f247b122            38.0
#
#         paciente_sexo_biologico  paciente_codigo_etnia paciente_etnia  \
# 5664                          F                    1.0         Branca
# 10900                         F                    3.0          Parda
# 20824                         M                   99.0            NaN
# 21360                         F                    1.0         Branca
# 22086                         F                    1.0         Branca
# ...                         ...                    ...            ...
# 2188117                       F                    3.0          Parda
# 2188147                       M                    4.0        Amarela
# 2188217                       M                    3.0          Parda
# 2188365                       M                    4.0        Amarela
# 2188447                       F                    3.0          Parda
#
#          paciente_codigo_ibge_municipio  paciente_codigo_pais  \
# 5664                          1300102.0                  10.0
# 10900                         1502301.0                  10.0
# 20824                         2110039.0                  10.0
# 21360                         3148004.0                  10.0
# 22086                         4307500.0                  10.0
# ...                                 ...                   ...
# 2188117                       3169208.0                  10.0
# 2188147                       2909901.0                  10.0
# 2188217                       2310902.0                  10.0
# 2188365                       2913200.0                  10.0
# 2188447                       2305506.0                  10.0
#
#            paciente_municipio paciente_pais  ...  \
# 5664                    Anori        Brasil  ...
# 10900            Capitão Poço        Brasil  ...
# 20824    Santa Luzia do Paruá        Brasil  ...
# 21360          Patos de Minas        Brasil  ...
# 22086                Espumoso        Brasil  ...
# ...                       ...           ...  ...
# 2188117                Tombos        Brasil  ...
# 2188147                Curaçá        Brasil  ...
# 2188217       Piquet Carneiro        Brasil  ...
# 2188365             Ibotirama        Brasil  ...
# 2188447                Iguatu        Brasil  ...
#
#                                      paciente_subgrupo  paciente_codigo_grupo  \
# 5664                           Pessoas de 75 a 79 anos                    2.0
# 10900                                           Outros                    9.0
# 20824              Povos indígenas em terras indígenas                    7.0
# 21360                            Técnico de Enfermagem                    9.0
# 22086                       Pessoas de 80 anos ou mais                    2.0
# ...                                                ...                    ...
# 2188117                          Técnico de Enfermagem                    9.0
# 2188147  Pessoas de 60 nos ou mais Institucionalizadas                    3.0
# 2188217                                  Enfermeiro(a)                    9.0
# 2188365                                         Outros                    9.0
# 2188447                             Pessoal da Limpeza                    9.0
#
#                                          paciente_grupo  vacina_lote  \
# 5664                                       Faixa Etária     4120Z005
# 10900                            Trabalhadores de Saúde     4120Z005
# 20824                                   Povos Indígenas    202010028
# 21360                            Trabalhadores de Saúde    202010038
# 22086                                      Faixa Etária       210010
# ...                                                 ...          ...
# 2188117                          Trabalhadores de Saúde    202010038
# 2188147  Pessoas de 60 anos ou mais institucionalizadas    202010041
# 2188217                          Trabalhadores de Saúde    202010034
# 2188365                          Trabalhadores de Saúde    202010027
# 2188447                          Trabalhadores de Saúde    202010034
#
#         data_aplicacao numero_dose  codigo_vacina  \
# 5664        2021-02-01           1             85
# 10900       2021-01-29           1             85
# 20824       2021-01-22           1             86
# 21360       2021-01-21           1             86
# 22086       2021-02-10           1             86
# ...                ...         ...            ...
# 2188117     2021-01-19           1             86
# 2188147     2021-01-20           1             86
# 2188217     2021-01-19           1             86
# 2188365     2021-01-28           1             86
# 2188447     2021-01-21           1             86
#
#                                       vacina sistema_origem  \
# 5664            Vacina Covid-19 - Covishield       Novo PNI
# 10900           Vacina Covid-19 - Covishield       Novo PNI
# 20824    Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 21360    Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 22086    Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# ...                                      ...            ...
# 2188117  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 2188147  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 2188217  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 2188365  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 2188447  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
#
#          paciente_idade_grupo
# 5664                   adulto
# 10900                  adulto
# 20824                  adulto
# 21360                  adulto
# 22086                  adulto
# ...                       ...
# 2188117                adulto
# 2188147                 idoso
# 2188217                adulto
# 2188365                adulto
# 2188447                adulto
#
# [21383 rows x 30 columns]

# %% [markdown]
# O código acima exibe somente as linhas duplicadas. Podemos ver os registros duplicados um seguido do outro com o código a seguir.

# %%
all_dose1[all_dose1[['paciente_uuid']].duplicated(keep=False)].sort_values(by='paciente_uuid')
# Out:
#                                documento_uuid  \
# 147810   39c87f38-9fa5-5525-9809-269859091a0b
# 1529500  63515f1a-52e1-5bb2-9ec5-0108697703d0
# 1224679  a5ab4518-7c63-5b80-9e50-4a84844b50a3
# 917013   a62ae5ed-01ec-5f56-92b9-b234c1a321f0
# 915696   5a142d51-45ad-59c1-9027-ba2682a5d77d
# ...                                       ...
# 1857391  a8d5d0b8-6f37-5eb2-bb3c-30563d516737
# 1121573  24c28acd-ef76-580d-a9a0-aeaaabfd4e7d
# 471249   c1ce2ad2-ba25-50d1-a4d0-aa03c5af612c
# 1549015  25a18309-ef3e-50f2-8a99-2947e9a81713
# 1041847  896bc39e-1b07-5ae9-a2ed-17e9e05c6216
#
#                                 paciente_uuid  paciente_idade  \
# 147810   0002eb7c-a885-5e0f-bb83-04da393d9748            94.0
# 1529500  0002eb7c-a885-5e0f-bb83-04da393d9748            94.0
# 1224679  0005ef75-adb3-5e6a-892e-04d8fd32ab55            44.0
# 917013   0005ef75-adb3-5e6a-892e-04d8fd32ab55            44.0
# 915696   00067d53-d14c-50c3-80ff-d8bbf8f9fb16            44.0
# ...                                       ...             ...
# 1857391  ffeb4260-fe62-5464-85d5-50b57e00459d            59.0
# 1121573  ffed5971-90bc-538a-bc7a-c4b30b6a8165            62.0
# 471249   ffed5971-90bc-538a-bc7a-c4b30b6a8165            62.0
# 1549015  fff45d96-3cdb-5262-b19c-abeb4162c1bc            85.0
# 1041847  fff45d96-3cdb-5262-b19c-abeb4162c1bc            85.0
#
#         paciente_sexo_biologico  paciente_codigo_etnia paciente_etnia  \
# 147810                        M                    2.0          Preta
# 1529500                       M                    2.0          Preta
# 1224679                       F                   99.0            NaN
# 917013                        F                   99.0            NaN
# 915696                        F                    1.0         Branca
# ...                         ...                    ...            ...
# 1857391                       F                    1.0         Branca
# 1121573                       M                   99.0            NaN
# 471249                        M                   99.0            NaN
# 1549015                       F                   99.0            NaN
# 1041847                       F                   99.0            NaN
#
#          paciente_codigo_ibge_municipio  paciente_codigo_pais  \
# 147810                        3165560.0                  10.0
# 1529500                       3165560.0                  10.0
# 1224679                       2611606.0                  10.0
# 917013                        2611606.0                  10.0
# 915696                        4310207.0                  10.0
# ...                                 ...                   ...
# 1857391                       4109609.0                  10.0
# 1121573                       3139607.0                  10.0
# 471249                        3139607.0                  10.0
# 1549015                       5201108.0                  10.0
# 1041847                       5201108.0                  10.0
#
#         paciente_municipio paciente_pais  ...  \
# 147810           Sem-Peixe        Brasil  ...
# 1529500          Sem-Peixe        Brasil  ...
# 1224679             Recife        Brasil  ...
# 917013              Recife        Brasil  ...
# 915696                Ijuí        Brasil  ...
# ...                    ...           ...  ...
# 1857391          Guaratuba        Brasil  ...
# 1121573            Mantena        Brasil  ...
# 471249             Mantena        Brasil  ...
# 1549015           Anápolis        Brasil  ...
# 1041847           Anápolis        Brasil  ...
#
#                                      paciente_subgrupo  paciente_codigo_grupo  \
# 147810   Pessoas de 60 nos ou mais Institucionalizadas                    3.0
# 1529500  Pessoas de 60 nos ou mais Institucionalizadas                    3.0
# 1224679                                         Outros                    9.0
# 917013                                          Outros                    9.0
# 915696                                          Outros                    9.0
# ...                                                ...                    ...
# 1857391                                         Outros                    9.0
# 1121573                                         Outros                    9.0
# 471249                                          Outros                    9.0
# 1549015                     Pessoas de 80 anos ou mais                    2.0
# 1041847                     Pessoas de 80 anos ou mais                    2.0
#
#                                          paciente_grupo  vacina_lote  \
# 147810   Pessoas de 60 anos ou mais institucionalizadas    202010038
# 1529500  Pessoas de 60 anos ou mais institucionalizadas    202010038
# 1224679                          Trabalhadores de Saúde    202009014
# 917013                           Trabalhadores de Saúde    202009014
# 915696                           Trabalhadores de Saúde     4120Z005
# ...                                                 ...          ...
# 1857391                          Trabalhadores de Saúde     4120Z005
# 1121573                          Trabalhadores de Saúde    202010018
# 471249                           Trabalhadores de Saúde    202010018
# 1549015                                    Faixa Etária    202010031
# 1041847                                    Faixa Etária    202010031
#
#         data_aplicacao numero_dose  codigo_vacina  \
# 147810      2021-01-22           1             86
# 1529500     2021-01-22           1             86
# 1224679     2021-01-25           1             86
# 917013      2021-01-25           1             86
# 915696      2021-02-02           1             85
# ...                ...         ...            ...
# 1857391     2021-01-26           1             85
# 1121573     2021-02-08           1             86
# 471249      2021-02-05           1             86
# 1549015     2021-01-29           1             86
# 1041847     2021-01-29           1             86
#
#                                       vacina sistema_origem  \
# 147810   Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 1529500  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 1224679  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 917013   Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 915696          Vacina Covid-19 - Covishield       Novo PNI
# ...                                      ...            ...
# 1857391         Vacina Covid-19 - Covishield       Novo PNI
# 1121573  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 471249   Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 1549015  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 1041847  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
#
#          paciente_idade_grupo
# 147810                  idoso
# 1529500                 idoso
# 1224679                adulto
# 917013                 adulto
# 915696                 adulto
# ...                       ...
# 1857391                adulto
# 1121573                 idoso
# 471249                  idoso
# 1549015                 idoso
# 1041847                 idoso
#
# [41204 rows x 30 columns]

# %% [markdown]
# Vamos fazer a mesma coisa com a segunda dose:

# %%
all_dose2 = data_microdados[data_microdados['numero_dose'] == 2]
all_dose2[all_dose2[['paciente_uuid']].duplicated()]
# Out:
#                                documento_uuid  \
# 27689    a401a49e-4758-575b-90ba-8663ee0ac9f4
# 51553    cb95b52d-6f28-5310-b1a5-dff936cffeb8
# 71013    151148fc-5f83-53f6-b238-5f182937b700
# 77039    d737e1da-243b-5a48-b24e-4dad062df5c3
# 91841    1c0017aa-0b0d-53c2-a46e-7399ec954c64
# ...                                       ...
# 2180545  c58c6ae4-248e-545f-835d-d9e1f769b5bb
# 2181787  b7adcc73-698d-513e-b629-4ac1e7aba5a6
# 2183732  91443ef9-3a4b-593d-b5a6-3c70df09c4ec
# 2185549  9a7d9973-4cc3-5fa2-99f3-cdc9dbb1399f
# 2185583  24210c28-f848-53ff-96c2-8830d5d20831
#
#                                 paciente_uuid  paciente_idade  \
# 27689    85061703-ecd1-5712-b692-2d5da62ab1b7            42.0
# 51553    85061703-ecd1-5712-b692-2d5da62ab1b7            42.0
# 71013    f63e4747-01d0-5f7a-9ae5-70eae2ebf1ae            52.0
# 77039    5abf8430-c34c-5b73-9631-bafad71bba93            41.0
# 91841    c522df36-d60f-5635-b83e-17e33e7cb19f            28.0
# ...                                       ...             ...
# 2180545  941e2a2d-516f-57b1-a230-ac95f62d0441            41.0
# 2181787  6f6a0f52-734f-5c49-a131-b0edf4a6a985            27.0
# 2183732  954f820d-068c-50ba-94e2-d5c0af6dd3a8            29.0
# 2185549  85061703-ecd1-5712-b692-2d5da62ab1b7            42.0
# 2185583  8d2de6bd-b914-5a69-8736-f12b79264136            37.0
#
#         paciente_sexo_biologico  paciente_codigo_etnia paciente_etnia  \
# 27689                         F                    3.0          Parda
# 51553                         F                    3.0          Parda
# 71013                         F                    1.0         Branca
# 77039                         M                   99.0            NaN
# 91841                         F                    3.0          Parda
# ...                         ...                    ...            ...
# 2180545                       F                    3.0          Parda
# 2181787                       F                    3.0          Parda
# 2183732                       F                    1.0         Branca
# 2185549                       F                    3.0          Parda
# 2185583                       F                    3.0          Parda
#
#          paciente_codigo_ibge_municipio  paciente_codigo_pais  \
# 27689                         3127800.0                  10.0
# 51553                         3127800.0                  10.0
# 71013                         3115508.0                  10.0
# 77039                         3106200.0                  10.0
# 91841                         3170404.0                  10.0
# ...                                 ...                   ...
# 2180545                       3109006.0                  10.0
# 2181787                       3141405.0                  10.0
# 2183732                       3120805.0                  10.0
# 2185549                       3127800.0                  10.0
# 2185583                       3148707.0                  10.0
#
#         paciente_municipio paciente_pais  ...      paciente_subgrupo  \
# 27689           Grão Mogol        Brasil  ...  Técnico de Enfermagem
# 51553           Grão Mogol        Brasil  ...  Técnico de Enfermagem
# 71013              Caxambu        Brasil  ...  Técnico de Enfermagem
# 77039       Belo Horizonte        Brasil  ...                 Médico
# 91841                 Unaí        Brasil  ...                 Outros
# ...                    ...           ...  ...                    ...
# 2180545         Brumadinho        Brasil  ...              Biomédico
# 2181787             Medina        Brasil  ...     Pessoal da Limpeza
# 2183732           Cruzília        Brasil  ...     Cuidador de Idosos
# 2185549         Grão Mogol        Brasil  ...  Técnico de Enfermagem
# 2185583         Pedra Azul        Brasil  ...          Enfermeiro(a)
#
#          paciente_codigo_grupo          paciente_grupo  vacina_lote  \
# 27689                      9.0  Trabalhadores de Saúde    202010031
# 51553                      9.0  Trabalhadores de Saúde    202010031
# 71013                      9.0  Trabalhadores de Saúde    202010038
# 77039                      9.0  Trabalhadores de Saúde    202009013
# 91841                      9.0  Trabalhadores de Saúde    202010038
# ...                        ...                     ...          ...
# 2180545                    9.0  Trabalhadores de Saúde    202010038
# 2181787                    9.0  Trabalhadores de Saúde    202010038
# 2183732                    9.0  Trabalhadores de Saúde    202010038
# 2185549                    9.0  Trabalhadores de Saúde    202010031
# 2185583                    9.0  Trabalhadores de Saúde    202010038
#
#         data_aplicacao numero_dose  codigo_vacina  \
# 27689       2021-02-05           2             86
# 51553       2021-02-05           2             86
# 71013       2021-02-09           2             86
# 77039       2021-02-08           2             86
# 91841       2021-01-22           2             86
# ...                ...         ...            ...
# 2180545     2021-02-08           2             86
# 2181787     2021-02-03           2             86
# 2183732     2021-02-04           2             86
# 2185549     2021-02-05           2             86
# 2185583     2021-01-20           2             86
#
#                                       vacina sistema_origem  \
# 27689    Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 51553    Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 71013    Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 77039    Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 91841    Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# ...                                      ...            ...
# 2180545  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 2181787  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 2183732  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 2185549  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 2185583  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
#
#          paciente_idade_grupo
# 27689                  adulto
# 51553                  adulto
# 71013                  adulto
# 77039                  adulto
# 91841                  adulto
# ...                       ...
# 2180545                adulto
# 2181787                adulto
# 2183732                adulto
# 2185549                adulto
# 2185583                adulto
#
# [816 rows x 30 columns]

# %% [markdown]
# Um pouco mais de 800 linhas duplicas. Exibindo os registros duplicados no mesmo dataframe, temos:

# %%
all_dose2[all_dose2[['paciente_uuid']].duplicated(keep=False)].sort_values(by='paciente_uuid')
# Out:
#                                documento_uuid  \
# 1241082  88cd7021-121c-537e-8279-3ae975429e5a
# 458320   076e8fb6-6e93-500e-b9cb-e8167f868a26
# 526111   e046232c-5e31-565d-9cc1-d50c220f83af
# 56733    c7a418ac-955a-5302-bb14-2105ede0233f
# 120783   b154f5b9-6f37-5085-b35e-70328ff99780
# ...                                       ...
# 323511   7dbdc938-c2b7-5f23-a6d8-4612881b3223
# 1962006  b7382330-33c9-5a69-897f-811cd01ade04
# 1458398  137046a6-8f43-5e33-bb41-bac45ab67851
# 979863   2981ec6b-85ad-5fbb-af12-5bbdd04b0de0
# 1557214  86b10519-b5cd-5593-bc59-32083b164cd1
#
#                                 paciente_uuid  paciente_idade  \
# 1241082  0010a75d-3bfc-51c6-b71a-e897fe366fe9            41.0
# 458320   0010a75d-3bfc-51c6-b71a-e897fe366fe9            41.0
# 526111   002566c9-3d82-5ce4-910d-0c1d8c03ff31            56.0
# 56733    002566c9-3d82-5ce4-910d-0c1d8c03ff31            56.0
# 120783   00e112ae-b9af-56f2-b9ee-7de5498c1262            48.0
# ...                                       ...             ...
# 323511   ff5a4806-7cdf-51ff-8b0d-e4459e21945d            43.0
# 1962006  ff6df4d2-f57c-5438-82ad-3b9fc0b6b566            41.0
# 1458398  ff6df4d2-f57c-5438-82ad-3b9fc0b6b566            41.0
# 979863   ffbc05e9-cc94-5944-b98d-6bdabd1c6a28            31.0
# 1557214  ffbc05e9-cc94-5944-b98d-6bdabd1c6a28            31.0
#
#         paciente_sexo_biologico  paciente_codigo_etnia paciente_etnia  \
# 1241082                       F                    5.0       Indígena
# 458320                        F                    5.0       Indígena
# 526111                        F                    3.0          Parda
# 56733                         F                    3.0          Parda
# 120783                        M                    1.0         Branca
# ...                         ...                    ...            ...
# 323511                        M                   99.0            NaN
# 1962006                       F                    1.0         Branca
# 1458398                       F                    1.0         Branca
# 979863                        F                   99.0            NaN
# 1557214                       F                   99.0            NaN
#
#          paciente_codigo_ibge_municipio  paciente_codigo_pais  \
# 1241082                       1300607.0                  10.0
# 458320                        1300607.0                  10.0
# 526111                        3161908.0                  10.0
# 56733                         3161908.0                  10.0
# 120783                        2613602.0                  10.0
# ...                                 ...                   ...
# 323511                        3106200.0                  10.0
# 1962006                       3104908.0                  10.0
# 1458398                       3104908.0                  10.0
# 979863                        2602308.0                  10.0
# 1557214                       2602308.0                  10.0
#
#                 paciente_municipio paciente_pais  ...  \
# 1241082          Benjamin Constant        Brasil  ...
# 458320           Benjamin Constant        Brasil  ...
# 526111   São Gonçalo do Rio Abaixo        Brasil  ...
# 56733    São Gonçalo do Rio Abaixo        Brasil  ...
# 120783           São José do Egito        Brasil  ...
# ...                            ...           ...  ...
# 323511              Belo Horizonte        Brasil  ...
# 1962006                   Baependi        Brasil  ...
# 1458398                   Baependi        Brasil  ...
# 979863                      Bonito        Brasil  ...
# 1557214                     Bonito        Brasil  ...
#
#                            paciente_subgrupo  paciente_codigo_grupo  \
# 1241082  Povos indígenas em terras indígenas                    7.0
# 458320   Povos indígenas em terras indígenas                    7.0
# 526111               Cozinheiro e Auxiliares                    9.0
# 56733                Cozinheiro e Auxiliares                    9.0
# 120783                                Outros                    9.0
# ...                                      ...                    ...
# 323511                                Médico                    9.0
# 1962006                    Assistente Social                    9.0
# 1458398                    Assistente Social                    9.0
# 979863                                Outros                    9.0
# 1557214                               Outros                    9.0
#
#                  paciente_grupo  vacina_lote data_aplicacao numero_dose  \
# 1241082         Povos Indígenas    202010025     2021-02-10           2
# 458320          Povos Indígenas    202010025     2021-02-10           2
# 526111   Trabalhadores de Saúde    202010031     2021-02-05           2
# 56733    Trabalhadores de Saúde    202010031     2021-02-05           2
# 120783   Trabalhadores de Saúde       200280     2021-02-04           2
# ...                         ...          ...            ...         ...
# 323511   Trabalhadores de Saúde    202010038     2021-02-05           2
# 1962006  Trabalhadores de Saúde    202010038     2021-02-04           2
# 1458398  Trabalhadores de Saúde    202010038     2021-02-04           2
# 979863   Trabalhadores de Saúde    202010041     2021-02-04           2
# 1557214  Trabalhadores de Saúde    202010041     2021-02-04           2
#
#          codigo_vacina                               vacina sistema_origem  \
# 1241082             86  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 458320              86  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 526111              86  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 56733               86  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 120783              86  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# ...                ...                                  ...            ...
# 323511              86  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 1962006             86  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 1458398             86  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 979863              86  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
# 1557214             86  Covid-19-Coronavac-Sinovac/Butantan       Novo PNI
#
#          paciente_idade_grupo
# 1241082                adulto
# 458320                 adulto
# 526111                 adulto
# 56733                  adulto
# 120783                 adulto
# ...                       ...
# 323511                 adulto
# 1962006                adulto
# 1458398                adulto
# 979863                 adulto
# 1557214                adulto
#
# [1486 rows x 30 columns]

# %% [markdown]
# Uma outra verificação é se existem registros de segunda dose sem a primeira. Vamos utilizar o merge dos dois dataframes `all_dose1` e `all_dose2`. Para simplificar, a visualização, vamos usar somente as informações `paciente_id` e `numero_dose`. Vou fazer um merge das duas bases utilizando a base da dose2 para o join. Vou usar um Right Join, ou seja, vou selecionar os registros da dose 2 e fazer um merge com os registros da dose 1. Em seguida selecionar aqueles nos quais a a dose 1 está nula.

# %%
selected_dose1 = all_dose1[['paciente_uuid','numero_dose']]
selected_dose2 = all_dose2[['paciente_uuid','numero_dose']]
selected_merge = pd.merge(selected_dose1, selected_dose2, how ='right', suffixes=['1','2'], on =['paciente_uuid']) 
selected_merge
# Out:
#                                paciente_uuid  numero_dose1  numero_dose2
# 0       4df552e5-0897-55b6-a1e5-5724aa0f05fe           1.0             2
# 1       a8e78208-974a-5964-b362-8755762d9aef           1.0             2
# 2       fe95852a-7de8-597a-96de-9b5a07e79df2           1.0             2
# 3       4889ec9c-6f3b-58ca-a2a9-6af88fc8c9a5           1.0             2
# 4       787778c5-2180-55f6-a6e6-8fd01a6912df           1.0             2
# ...                                      ...           ...           ...
# 101906  83b3217c-cc03-5fcb-b39e-04142ced0521           1.0             2
# 101907  09534177-9088-5046-b815-148364236425           1.0             2
# 101908  09534177-9088-5046-b815-148364236425           1.0             2
# 101909  2e529d42-a388-558c-bd41-3079f9403068           1.0             2
# 101910  782070ff-855b-54ef-adf1-b08a414c737f           1.0             2
#
# [101911 rows x 3 columns]

# %%
selected_merge[selected_merge['numero_dose1'].isnull()]
# Out:
#                                paciente_uuid  numero_dose1  numero_dose2
# 15      8e1426b1-5eae-591b-8924-636439a1bd51           NaN             2
# 17      a9e1b6c1-b0d5-5857-873e-c652ac89e997           NaN             2
# 26      a18ee347-98e6-5e15-923c-30a64584b3ec           NaN             2
# 34      6b7be027-677c-5757-80b8-91ff67e8b64b           NaN             2
# 38      88750816-0f58-5adb-99f8-6b54b05d210b           NaN             2
# ...                                      ...           ...           ...
# 101880  6bc52e7b-d9af-5624-a4fa-1720d08d0c81           NaN             2
# 101883  7d2947eb-ca33-5a99-bbb0-244ae3081848           NaN             2
# 101885  fc16794e-5121-5b9d-9db9-f5993057940c           NaN             2
# 101894  de6c2369-503e-571b-bc05-0eb72b7cb7d7           NaN             2
# 101899  ef69a5ec-7692-5506-92e8-7b4b3fa1c1d6           NaN             2
#
# [8230 rows x 3 columns]

# %% [markdown]
# Foram encontrados 8230 registros que estão marcados como segunda dose mas  não tem a primeira dose correspondente.

# %% [markdown]
# ## Extraindo os totais de cada variável categórica
#
# Uma outra coisa que ajuda a enxergar um pouco como esses dados estão distribuídos é verificar o quantitativo por raça, sexto, idade, grupos. Vamos exibir essas informações utilizando o `value_counts` que será aplicado às variáveis categóricas. Vou fazer isso apenas para a primeira dose. Para isso, vou usar o campo `numero_dose`. A informação de UF será utilizada a do estabelecimento para garantir o quantitativo por estado, já que a UF do paciente não é necessariamente a de onde ele tomou a vacina. Essa informação está no campo `estabelecimento_unidade_federativa`.

# %%
data_microdados.columns
# Out:
# Index(['documento_uuid', 'paciente_uuid', 'paciente_idade',
#        'paciente_sexo_biologico', 'paciente_codigo_etnia', 'paciente_etnia',
#        'paciente_codigo_ibge_municipio', 'paciente_codigo_pais',
#        'paciente_municipio', 'paciente_pais', 'paciente_unidade_federativa',
#        'paciente_cep', 'paciente_nacionalidade', 'estabelecimento_codigo_cnes',
#        'estabelecimento_razao_social', 'estabelecimento',
#        'estabelecimento_codigo_ibge_municipio', 'estabelecimento_municipio',
#        'estabelecimento_unidade_federativa', 'paciente_codigo_subgrupo',
#        'paciente_subgrupo', 'paciente_codigo_grupo', 'paciente_grupo',
#        'vacina_lote', 'data_aplicacao', 'numero_dose', 'codigo_vacina',
#        'vacina', 'sistema_origem', 'paciente_idade_grupo'],
#       dtype='object')

# %%
cat_columns = ['paciente_idade_grupo','paciente_etnia','estabelecimento_unidade_federativa','paciente_sexo_biologico','paciente_grupo','paciente_subgrupo']
data_selected = data_microdados[data_microdados['numero_dose'] == 1]
dt_ = {}

for c in cat_columns:
    dt_[c] = pd.DataFrame(data_selected[c].value_counts())
    dt_[c].reset_index(inplace=True)
    dt_[c].columns = ['info','total']

# %%
dt_['paciente_sexo_biologico']
# Out:
#   info    total
# 0    F  1404728
# 1    M   682886

# %%
dt_['paciente_grupo']
# Out:
#                                                info    total
# 0                            Trabalhadores de Saúde  1535494
# 1                                      Faixa Etária   320758
# 2                                   Povos Indígenas   128442
# 3    Pessoas de 60 anos ou mais institucionalizadas    83734
# 4                                      Comorbidades     7804
# 5                           Pessoas com Deficiência     6106
# 6                  Forças de Segurança e Salvamento     2692
# 7                  Povos e Comunidades Tradicionais     1411
# 8                         Trabalhadores da Educação      526
# 9                   Forças Armadas (membros ativos)      289
# 10  Funcionário do Sistema de Privação de Liberdade      148
# 11                       Pessoas em Situação de Rua       63
# 12                   População Privada de Liberdade       57
# 13                         Trabalhadores Portuários       44
# 14                        Trabalhadores Industriais       24

# %%
for index, row in dt_['paciente_subgrupo'].iterrows():
    print("%s: %i" % (row['info'], row['total']))
# Out:
# Outros: 548687
# Pessoas de 80 anos ou mais: 283724
# Técnico de Enfermagem: 271415
# Enfermeiro(a): 131580
# Povos indígenas em terras indígenas: 128442
# Médico: 120517
# Pessoas de 60 nos ou mais Institucionalizadas: 83734
# Pessoal da Limpeza: 78949
# Recepcionista: 66543
# Motorista de Ambulância: 49621
# Odontologista: 45964
# Fisioterapeutas: 28973
# Farmacêutico: 26331
# Pessoas de 75 a 79 anos: 21675
# Auxiliar de Enfermagem: 21283
# Cozinheiro e Auxiliares: 19666
# Psicólogo: 18796
# Cuidador de Idosos: 17575
# Técnico de Odontologia: 16050
# Segurança: 14400
# Assistente Social: 12463
# Nutricionista: 10971
# Pessoas de 70 a 74 anos: 7193
# Biomédico: 6737
# Estudante: 6303
# Fonoaudiólogo: 5140
# Profissionais de Educação Física: 5033
# Funcionário do Sistema Funerário c/ cadáveres potencialmente contaminados: 4979
# Pessoas com Deficiência Institucionalizadas: 4963
# Pessoas de 60 a 64 anos: 4761
# Hipertensão de difícil controle ou com complicações/lesão de órgão alvo: 3775
# Pessoas de 65 a 69 anos: 3405
# Médico Veterinário: 3391
# Terapeuta Ocupacional: 1965
# Diabetes Mellitus: 1774
# Bombeiro Militar: 1719
# Biólogo: 1435
# Quilombola: 1410
# Pessoas com Deficiências Permanente Grave: 1143
# Bombeiro Civil: 611
# Doenças Cardiovasculares e Cerebrovasculares: 572
# Doença Renal: 547
# Câncer: 449
# Auxiliar de Veterinário: 370
# Doença Pulmonar Obstrutiva Crônica: 365
# Ensino Superior: 272
# Ensino Básico: 254
# Obesidade Grave (Imc>=40): 240
# Exército Brasileiro - EB: 223
# Policial Militar: 201
# Técnico de Veterinário: 181
# Doula/Parteira: 176
# Funcionário do Sistema de Privação de Liberdade: 148
# Guarda Municipal: 128
# Pessoas em Situação de Rua: 63
# Força Aérea Brasileira - FAB: 60
# População Privada de Liberdade: 57
# Anemia Falciforme: 52
# Trabalhadores Portuários: 44
# Policial Civil: 33
# Indivíduos Transplantados de Órgão Sólido: 25
# Trabalhadores Industriais: 24
# Marinha do Brasil - MB: 6
# Síndrome de Down: 5
# Ribeirinha: 1

# %%
dt_['paciente_idade_grupo']
# Out:
#           info    total
# 0       adulto  1560496
# 1        idoso   518628
# 2  adolescente     8356
# 3      criança      134

# %%
dt_['paciente_etnia']
# Out:
#        info   total
# 0    Branca  720810
# 1     Parda  453532
# 2   Amarela  292341
# 3  Indígena   91490
# 4     Preta   83260

# %%
dt_['estabelecimento_unidade_federativa']
# Out:
#    info   total
# 0    MG  222594
# 1    RS  186792
# 2    RJ  160311
# 3    BA  153133
# 4    PE  122725
# 5    PR  120253
# 6    GO   97488
# 7    MA   89433
# 8    PB   84156
# 9    CE   80854
# 10   PA   75490
# 11   ES   72879
# 12   RN   70628
# 13   DF   66091
# 14   MT   62651
# 15   SC   59694
# 16   AM   49710
# 17   SP   48277
# 18   AL   47644
# 19   MS   42820
# 20   PI   35333
# 21   RO   26867
# 22   SE   26512
# 23   TO   18235
# 24   AC   12262
# 25   AP    9567
# 26   RR    8835

# %% [markdown]
# ## Pré-processamento e Visualizando os dados
#
# _Em breve_
